# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import json
from connectdb import connect_to_mongodb

# %%
# Replace 'your_database_name' and 'your_collection_name' with your desired database and collection names
database_name = 'realestatebackend'
collection_name = 'lake'

collection = connect_to_mongodb(database_name, collection_name)
# Out:
# Connected to MongoDB successfully!

# %%
data = list(collection.find({}))

# %%
df = pd.DataFrame(data)

# %%
df.columns
# Out:
# Index(['_id', 'source', 'category', 'price', 'house_details', 'other_details',
#        'location', 'phone', 'images'],
#       dtype='object')

# %%
df.head()
# Out:
#                         _id        source  category           price  \
# 0  64c8106ad2b80fc9a5e08ff1  efiewura.com  for sale  GHS 125,000.00
# 1  64c8106cd2b80fc9a5e08ff2  efiewura.com  for sale  GHS 200,000.00
# 2  64c8106dd2b80fc9a5e08ff3  efiewura.com  for sale  GHS 165,000.00
# 3  64c8106fd2b80fc9a5e08ff4  efiewura.com  for sale  GHS 100,000.00
# 4  64c81070d2b80fc9a5e08ff5  efiewura.com  for sale  USD 280,000.00
#
#                  house_details  \
# 0  {'Beds': '4', 'Baths': '4'}
# 1  {'Beds': '4', 'Baths': '4'}
# 2  {'Beds': '3', 'Baths': '3'}
# 3  {'Beds': '3', 'Baths': '3'}
# 4  {'Beds': '3', 'Baths': '2'}
#
#                                        other_details  \
# 0  Appliances\nWater Heater\nWardrobes\nAmenities...
# 1
# 2
# 3
# 4
#
#                                             location phone  \
# 0  [Greater Accra Region,  Accra,  Lakeside Estat...
# 1  [Greater Accra Region,  Tema,  Tema Community 22]
# 2  [Greater Accra Region,  Tema,  Tema Community 22]
# 3  [Greater Accra Region,  Tema,  Tema Community 22]
# 4  [Greater Accra Region,  Tema,  Tema Community 22]
#
#                                               images
# 0  [https://efiewura.com/img/properties/executive...
# 1  [https://efiewura.com/img/properties/4_bedroom...
# 2  [https://efiewura.com/img/properties/3_bedroom...
# 3  [https://efiewura.com/img/properties/3_bedroom...
# 4  [https://efiewura.com/img/properties/3_bedroom...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   _id            440 non-null    object
#  1   source         440 non-null    object
#  2   category       440 non-null    object
#  3   price          440 non-null    object
#  4   house_details  440 non-null    object
#  5   other_details  440 non-null    object
#  6   location       440 non-null    object
#  7   phone          440 non-null    object
#  8   images         440 non-null    object
# dtypes: object(9)
# memory usage: 31.1+ KB

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ### Data Cleaning Steps
# ###### 1. split price column into currecy and amount
# ###### 2. split house details into bedrooms and bathrooms
# ###### 3. split location column into Region,City,community

# %%
df['price'].unique()
# Out:
# array(['GHS 125,000.00', 'GHS 200,000.00', 'GHS 165,000.00',
#        'GHS 100,000.00', 'USD 280,000.00', 'USD 250,000.00',
#        'USD 950,000.00', 'USD 727,800.00', 'USD 259,500.00',
#        'USD 180,000.00', 'USD 120,000.00', 'USD 100,000.00',
#        'USD 320,000.00', 'GHS 540,000.00', 'GHS 850,000.00',
#        'GHS 1,680,000.00', 'USD 80,000.00', 'USD 75,000.00',
#        'GHS 3,500,000.00', 'GHS 2,314,000.00', 'USD 222,479.00',
#        'USD 220,350.00', 'USD 141,347.00', 'USD 193,500.00',
#        'USD 384,500.00', 'USD 544,160.00', 'USD 1,596,000.00',
#        'GHS 1,500,000.00', 'GHS 830,000.00', 'USD 271,950.00',
#        'USD 245,000.00 / day', 'USD 150,000.00', 'USD 200,000.00',
#        'GHS 350,000.00', 'GHS 750,000.00', 'USD 70,000.00',
#        'USD 210,000.00', 'GHS 900,000.00', 'USD 350,000.00',
#        'USD 130,000.00', 'USD 650,000.00', 'USD 140,000.00',
#        'USD 234,650.00', 'USD 110,000.00', 'USD 300,000.00',
#        'GHS 420,000.00', 'USD 242,000.00', 'GHS 6,000,000.00',
#        'GHS 6,875,000.00', 'USD 450,000.00', 'USD 60,000.00',
#        'USD 160,000.00', 'GHS 1,600,000.00', 'USD 90,000.00',
#        'USD 600,000.00', 'USD 420,000.00', 'GHS 1,550,000.00',
#        'GHS 2,400,000.00', 'GHS 680,000.00', 'USD 2,000,000.00',
#        'USD 300,000.00 / month', 'USD 190,000.00', 'USD 275,000.00',
#        'GHS 550,000.00', 'USD 270,000.00', 'GHS 2,496,000.00',
#        'GHS 970,000.00', 'GHS 4,000.00', 'GHS 700,000.00',
#        'USD 380,000.00', 'GHS 600,000.00', 'USD 2,500,000.00',
#        'GHS 800,000.00', 'USD 550,000.00', 'USD 325,000.00',
#        'USD 470,000.00', 'GHS 185,000.00', 'USD 220,000.00',
#        'GHS 2,700,000.00', 'USD 480,000.00', 'USD 675,000.00',
#        'USD 260,000.00', 'USD 2,800,000.00', 'USD 170,000.00',
#        'USD 900,000.00', 'USD 310,000.00', 'GHS 2,200,000.00',
#        'USD 1,500,000.00', 'USD 750,000.00', 'USD 165,000.00',
#        'USD 360,000.00', 'USD 400,000.00', 'USD 18,000,000.00',
#        'USD 2,200,000.00', 'USD 370,000.00', 'USD 230,000.00',
#        'USD 1,700,000.00', 'GHS 1,200,000.00', 'USD 135,000.00',
#        'GHS 2,300,000.00', 'USD 850,000.00', 'GHS 2,900,000.00',
#        'GHS 450,000.00', 'GHS 250,000.00', 'USD 6,500,000.00',
#        'GHS 180,000.00 / day', 'GHS 1,000,000.00', 'GHC 2,184,000.00',
#        'USD 95,000.00', 'USD 155,000.00', 'GHS 135,000.00',
#        'GHS 160,000.00', 'USD 3,000.00 / month', 'GHS 2,100,000.00',
#        'USD 500,000.00', 'GHS 300,000.00', 'USD 3,000,000.00',
#        'USD 1,200,000.00', 'USD 900,008.00', 'GHS 4,000.00 / month',
#        'USD 125,000.00', 'GHS 3,162,000.00', 'GHS 2,600,000.00',
#        'GHS 300,000.00 / month', 'USD 58,000.00', 'USD 330,000.00',
#        'GHS 470,000.00', 'USD 8,000,000.00', 'USD 6,000,000.00',
#        'USD 174,000.00', 'USD 1,400,000.00', 'GHS 2,500,000.00',
#        'GHS 400,000.00', 'USD 3,500,000.00', 'GHS 1,980,042.00',
#        'GHS 1,875,830.00', 'GHS 320,000.00', 'GHS 755,000.00',
#        'GHC 350,000.00', 'GHS 170,000.00', 'USD 290,000.00',
#        'USD 13,000,000.00', 'GHC 1,097,400.00', 'GHC 812,200.00',
#        'GHC 421,600.00', 'GHC 694,400.00', 'GHC 550,000.00',
#        'USD 1,000,000.00', 'USD 175,000.00', 'USD 145,000.00',
#        'GHC 1,900,000.00', 'GHC 1,820,000.00', 'USD 520,000.00',
#        'USD 1,800,000.00', 'GHC 750,000.00', 'USD 240,000.00',
#        'USD 599,000.00', 'GHC 700,000.00', 'GHC 600,000.00',
#        'USD 211,125.00', 'USD 66,750.00', 'GHC 720,000.00',
#        'GHC 1,330,000.00', 'USD 185,000.00', 'GHC 400,000.00',
#        'GHC 450,000.00', 'GHC 650,000.00', 'GHC 75,000.00',
#        'GHC 4,662,400.00', 'GHC 1,278,400.00', 'GHC 2,857,600.00',
#        'GHC 1,504,000.00', 'GHC 2,030,400.00', 'GHC 1,600,000.00'],
#       dtype=object)

# %% [markdown]
# #### price

# %%
currency = []
amount = []
duration = []

for i in df['price']:
    split = i.split(" ")
    currency.append(split[0])
    amount.append(split[1])
    if "/" in split:
        duration.append(split[-1])
    else:
        duration.append("N/A")

# %%
df['currency'] = currency
df['price'] = amount
df['duration']=duration

# %%
# Out:
#                           _id        source  category         price  \
# 0    64c8106ad2b80fc9a5e08ff1  efiewura.com  for sale    125,000.00
# 1    64c8106cd2b80fc9a5e08ff2  efiewura.com  for sale    200,000.00
# 2    64c8106dd2b80fc9a5e08ff3  efiewura.com  for sale    165,000.00
# 3    64c8106fd2b80fc9a5e08ff4  efiewura.com  for sale    100,000.00
# 4    64c81070d2b80fc9a5e08ff5  efiewura.com  for sale    280,000.00
# ..                        ...           ...       ...           ...
# 435  64c813e4d2b80fc9a5e091a4  efiewura.com  for sale  2,857,600.00
# 436  64c813e6d2b80fc9a5e091a5  efiewura.com  for sale  1,504,000.00
# 437  64c813e8d2b80fc9a5e091a6  efiewura.com  for sale    550,000.00
# 438  64c813ead2b80fc9a5e091a7  efiewura.com  for sale  2,030,400.00
# 439  64c813ecd2b80fc9a5e091a8  efiewura.com  for sale  1,600,000.00
#
#                    house_details  \
# 0    {'Beds': '4', 'Baths': '4'}
# 1    {'Beds': '4', 'Baths': '4'}
# 2    {'Beds': '3', 'Baths': '3'}
# 3    {'Beds': '3', 'Baths': '3'}
# 4    {'Beds': '3', 'Baths': '2'}
# ..                           ...
# 435  {'Beds': '4', 'Baths': '4'}
# 436  {'Beds': '4', 'Baths': '4'}
# 437  {'Beds': '3', 'Baths': '3'}
# 438  {'Beds': '4', 'Baths': '4'}
# 439  {'Beds': '5', 'Baths': '7'}
#
#                                          other_details  \
# 0    Appliances\nWater Heater\nWardrobes\nAmenities...
# 1
# 2
# 3
# 4
# ..                                                 ...
# 435  \nExecutive furnished 4  bedroom is up for sal...
# 436  \n4bedroom fully furnished for sale at East le...
# 437  \nThis is a newly built 3bedroom self house lo...
# 438  \n4 bedrooms house for sale at east legon hill...
# 439  \nThe property is located at Daaban residentia...
#
#                                               location phone  \
# 0    [Greater Accra Region,  Accra,  Lakeside Estat...
# 1    [Greater Accra Region,  Tema,  Tema Community 22]
# 2    [Greater Accra Region,  Tema,  Tema Community 22]
# 3    [Greater Accra Region,  Tema,  Tema Community 22]
# 4    [Greater Accra Region,  Tema,  Tema Community 22]
# ..                                                 ...   ...
# 435      [Greater Accra Region,  Accra,  Tantra Hills]
# 436  [Greater Accra Region,  Accra,  East Legon Hills]
# 437  [Greater Accra Region,  Accra,  Ashaley Botwe ...
# 438  [Greater Accra Region,  Accra,  East Legon Hills]
# 439        [Ashanti Region,  Kumasi,  Daaban new site]
#
#                                                 images currency duration
# 0    [https://efiewura.com/img/properties/executive...      GHS      N/A
# 1    [https://efiewura.com/img/properties/4_bedroom...      GHS      N/A
# 2    [https://efiewura.com/img/properties/3_bedroom...      GHS      N/A
# 3    [https://efiewura.com/img/properties/3_bedroom...      GHS      N/A
# 4    [https://efiewura.com/img/properties/3_bedroom...      USD      N/A
# ..                                                 ...      ...      ...
# 435  [https://efiewura.com/img/properties/executive...      GHC      N/A
# 436  [https://efiewura.com/img/properties/4bedroom_...      GHC      N/A
# 437  [https://efiewura.com/img/properties/this_is_a...      GHC      N/A
# 438  [https://efiewura.com/img/properties/_4_bedroo...      GHC      N/A
# 439  [https://efiewura.com/img/properties/5_bedroom...      GHC      N/A
#
# [440 rows x 11 columns]

# %%
def remove_comma(x):
    return float("".join(x.split(",")))

# %%
df['price']= df['price'].apply(remove_comma)

# %%
backup_df = df.copy()

# %%
df = backup_df

# %% [markdown]
# ##### location

# %%
df['location']
# Out:
# 0      [Greater Accra Region,  Accra,  Lakeside Estat...
# 1      [Greater Accra Region,  Tema,  Tema Community 22]
# 2      [Greater Accra Region,  Tema,  Tema Community 22]
# 3      [Greater Accra Region,  Tema,  Tema Community 22]
# 4      [Greater Accra Region,  Tema,  Tema Community 22]
#                              ...
# 435        [Greater Accra Region,  Accra,  Tantra Hills]
# 436    [Greater Accra Region,  Accra,  East Legon Hills]
# 437    [Greater Accra Region,  Accra,  Ashaley Botwe ...
# 438    [Greater Accra Region,  Accra,  East Legon Hills]
# 439          [Ashanti Region,  Kumasi,  Daaban new site]
# Name: location, Length: 440, dtype: object

# %%
df['region'] = df['location'].apply(lambda location: location[0])
df['city'] = df['location'].apply(lambda location:location[1])
df['sub'] = df['location'].apply(lambda location:location[2])

# %%
df.columns
# Out:
# Index(['_id', 'source', 'category', 'price', 'house_details', 'other_details',
#        'location', 'phone', 'images', 'currency', 'duration', 'region', 'city',
#        'sub', 'no_of_bedrooms', 'no_of_bathrooms'],
#       dtype='object')

# %%
df.head(3)
# Out:
#                         _id        source  category       price  \
# 0  64c8106ad2b80fc9a5e08ff1  efiewura.com  for sale  125,000.00
# 1  64c8106cd2b80fc9a5e08ff2  efiewura.com  for sale  200,000.00
# 2  64c8106dd2b80fc9a5e08ff3  efiewura.com  for sale  165,000.00
#
#                  house_details  \
# 0  {'Beds': '4', 'Baths': '4'}
# 1  {'Beds': '4', 'Baths': '4'}
# 2  {'Beds': '3', 'Baths': '3'}
#
#                                        other_details  \
# 0  Appliances\nWater Heater\nWardrobes\nAmenities...
# 1
# 2
#
#                                             location phone  \
# 0  [Greater Accra Region,  Accra,  Lakeside Estat...
# 1  [Greater Accra Region,  Tema,  Tema Community 22]
# 2  [Greater Accra Region,  Tema,  Tema Community 22]
#
#                                               images currency duration  \
# 0  [https://efiewura.com/img/properties/executive...      GHS      N/A
# 1  [https://efiewura.com/img/properties/4_bedroom...      GHS      N/A
# 2  [https://efiewura.com/img/properties/3_bedroom...      GHS      N/A
#
#                  region    city                 sub no_of_bedrooms  \
# 0  Greater Accra Region   Accra     Lakeside Estate              4
# 1  Greater Accra Region    Tema   Tema Community 22              4
# 2  Greater Accra Region    Tema   Tema Community 22              3
#
#   no_of_bathrooms
# 0               4
# 1               4
# 2               3

# %% [markdown]
# ###### house_details

# %%
df['no_of_bedrooms'] = df['house_details'].apply(lambda x:x.get("Beds"))
df['no_of_bathrooms'] = df['house_details'].apply(lambda x:x.get("Baths"))

# %%
# drop unnecessary columns

# %%
df.head(2)
# Out:
#                         _id        source  category       price  \
# 0  64c8106ad2b80fc9a5e08ff1  efiewura.com  for sale  125,000.00
# 1  64c8106cd2b80fc9a5e08ff2  efiewura.com  for sale  200,000.00
#
#                  house_details  \
# 0  {'Beds': '4', 'Baths': '4'}
# 1  {'Beds': '4', 'Baths': '4'}
#
#                                        other_details  \
# 0  Appliances\nWater Heater\nWardrobes\nAmenities...
# 1
#
#                                             location phone  \
# 0  [Greater Accra Region,  Accra,  Lakeside Estat...
# 1  [Greater Accra Region,  Tema,  Tema Community 22]
#
#                                               images currency duration  \
# 0  [https://efiewura.com/img/properties/executive...      GHS      N/A
# 1  [https://efiewura.com/img/properties/4_bedroom...      GHS      N/A
#
#                  region    city                 sub no_of_bedrooms  \
# 0  Greater Accra Region   Accra     Lakeside Estate              4
# 1  Greater Accra Region    Tema   Tema Community 22              4
#
#   no_of_bathrooms
# 0               4
# 1               4

# %%
for i in list(df['other_details']):
    print(i)
# Out:
# Appliances
# Water Heater
# Wardrobes
# Amenities
# Security Fence
# Water storage and pumping system
# Car Port
# Parking
# Pre-paid Meter
#
# * All Bedrooms En-suite
# * P.O.P Ceiling in all Rooms
# * Modern Porcelain Floor Tiles
# * Wall Tiles in Wet Areas
# * Wardrobes in all Bedrooms
# * Tiled and Fitted Kitchen Cabinet
# * Wiring for Microwave, Gas Cooker and Heat Extractor
# * Hot Water System including Water Heater
# * Piping and Wiring for Washing Machine
# * Wiring for A/C and Ceiling Fans
# * TV and DSTV points
# * Prepainted Longspan AluZinc Roof with Rain Gutters
# * Sliding Gate
# * External Steel Security Doors
# * Polished Internal Doors with Architraves
# * Sliding Glass Windows with Fixed Burglar Proofs
# * Biofill System
# * Overhead Polytank
# * Tiled and Grassed Compound
# * Provision for Generator, Water Pump
# * Carport
# * Security Electric Fence Wall
#
#
#
#
# Appliances
# Dishwasher
# Microwave
# Air Condition
# Recess Light
# Gas Range
# Electric Cooker
# Wardrobes
# Amenities
# Security Fence
# 24-hour Security
# Water storage and pumping system
# Parking
# Balcony
# Office space
# Pre-paid Meter
#
# This beautiful home redefines townhouses with a synergy that flows between all levels and fills it with a unique aura of warmth, wellbeing and hospitality.
# Love entertaining? The ARABA’S Court townhouse was designed to make it easy for you. Light, open space, clever design and careful proportions come together seamlessly to create a special connection between the expansive living areas on each floor.
# There’s plenty of space for letting your imagination run free and make your home feel like a tropical resort every- one wants to holiday in! There is ample space for you to have a private pool if you wish. Each townhouse has four generous Bedrooms, including a resort-style Master Suite.
# The inclusion of a Home Theatre on the second floor provides extra space to unwind at the end of the day, while the expansive Gourmet Kitchen is an inviting place for everyone to gather, laugh and forge memories you’ll treasure forever.
# ARABA’S Court will constantly surprise you with the clever little details that enhance the way you live here. The discreet Home Office on the first floor makes it easy to duck away when work calls, while upstairs on the rooftop terrace is a place for retreat.
# The kids will love it too, with a cleverly positioned Study Nook providing the perfect place for homework, and the Children’s Activity room off the upstairs landing giving them their own space to kick back and relax.
# Flawlessly appointed, ARABA’S Court offers a luxurious lifestyle that’s perfect for the discerning homeowner.
# Araba’s Court incorporates clean lines, modern textures and natural light to create distinct living spaces that complement the art of living well.
# This designer residential development is located in a secure, boomed off neighbourhood and comprises 6 private homes with walled gardens and covered patios.
#   Neighboring social amenities:
# Major hospitals within the vicinity include Sweden Ghana Medical Centre. International schools that neighbor our development include the British International School. Neighboring projects include the Adams Grey Townhouses, Red Row Estates, and the Richfield Lifestyle Estate. The Silicon Accra Project, a 10-acre technology park currently under development is within 2km of the ARABAS Court Townhouses.
# Appliances
# Dishwasher
# Water Heater
# Microwave
# Air Condition
# Recess Light
# Gas Range
# Electric Cooker
# Washing Machine
# Kitchen extractor
# Wardrobes
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# CCTV
# Water storage and pumping system
# Car Port
# Swimming Pool
# Generator
# Solar Energy
# Parking
# Facilities Management Services
# Balcony
# Pre-paid Meter
# Garden
# Laundry
#
#
# 5 Bedroom Ensuite
# Compound
# Main Gate
# Electric security fence for the whole compound
# Gated units
# Paved road (Interlock or Stamped concrete)
# Guests parking
# Backup generator
# Lightening
# CCTV system
# Video intercom
# Yard area inside each unit:
# Paved path (Interlock or Stamped concrete)
# Pergola
# Parking for 2 cars
# Green area - landscape
# Private swimming pool
# Outdoor lightening
# Water tank on roofing area
# Water pump
# Villa’s outside finishing
# Luxurious tiles
# High quality waterproofing paints
# Elegant unique entrance
# Finishing
# Modern design finishing with high quality
# High standard tiles
# Elite sanitary wares
# UPVC windows
# Stainless steel handrail for stairs
# High quality doors
# Air conditioners
# Water heaters
# European kitchen
# . Cabinets
# . High stool table for dining
# . Cooker
# . Hood
# . Fridge
# . Microwave
# . Washing machine
# Roofing Terrace
# Pergola
# Open large area equipped for BBQ(s)
#
# Harmonia Residence is a 16-story mix-use residential apartment located strategically at West Airport, It is made up of studios, 1,2,3 bedroom with a penthouse, and a sky-villa.
# Harmonia is mapped out to make you feel connected and offers you the needed personal space. We are not just offering you an address but also an investment you can be proud of with Better ROI.
# At Harmonia Residence, we made sure to include all the required facilities and more to maintain the luxurious life you deserve. This beautiful development is strategically positioned to give you asses to other amenities.
# Harmonia residence is also designed to have a mini-market, Pharmacy, Restaurant, Spa, Gym, Sky Launch Meeting Rooms and a kids' play area.
# With a competitive market price, I am proud to inform you that the project is 75% sold out.
#
# Appliances
# Water Heater
# Microwave
# Air Condition
# Recess Light
# Washing Machine
# Wardrobes
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# CCTV
# Water storage and pumping system
# Car Port
# Swimming Pool
# Generator
# Solar Energy
# Parking
# Facilities Management Services
# Gym
# Super market
# Balcony
# Office space
# Pre-paid Meter
# Garden
# Laundry
# Restaurant
# Conference Hall
#
# Main Gate
# Fitted Kitchen
# Concierge Service
# Fire Fighting
# Kids Area
# Fridge
# Pharmacy
# Elevator
# Green area – landscape
# Fire Escape Staircase
# Rooftop Lounge
# Access and Control Keycards
#
# Description
# 2 Bedroom Apartment for Sale at Tse-Addo (Near Cantonments & Labone)
# Features:
# Storeroom
# Guest Washroom
# Backup Water Supply
# Rooftop Recreational Area with Sea Views
# Air Conditioning Units
# Fitted Kitchen with Appliances (Cooker Unit, Extractor, Oven, Microwave)
# Smart Home
# Private Parking & a Garden
# 24 Hr CCTV
# Secured Gated Community with 24 Hr security
# Security Post
# Gym
# Communal Swimming Pool
# Flexible Payment Plans
# Construction ongoing
# Completion date is December 2023
# 2 Bedroom Apartments (75 SQM)
# Payment Plans
# A. 1 year payment plan for $150,000:
# Reservation fee - $5,000
# Initial Deposit - $25,000
# Monthly Payments - $10,000
# B. 2 years payment plan for $150,000:
# Reservation fee - $5,000
# Initial Deposit - $25,000
# Monthly Payments - $5,000
# Note: Buyer can also suggest Payment Plan best for Him/Her but must be within 24 Months
#
# Description
# 1 Bedroom Apartment for Sale at Tse-Addo (Near Cantonments & Labone)
# Features:
# Storeroom
# Guest Washroom
# Backup Water Supply
# Rooftop Recreational Area with Sea Views
# Air Conditioning Units
# Fitted Kitchen with Appliances (Cooker Unit, Extractor, Oven, Microwave)
# Smart Home
# Private Parking & a Garden
# 24 Hr CCTV
# Secured Gated Community with 24 Hr security
# Security Post
# Gym
# Communal Swimming Pool
# Flexible Payment Plans
# Construction ongoing
# Completion date is December 2023
# 1 Bedroom Apartments (40 SQM)
# Payment Plans
# A. 1 year payment plan for $100,000:
# Reservation fee - $5,000
# Initial Deposit - $15,000
# Monthly Payments - $6,667
# B. 2 years payment plan for $100,000:
# Reservation fee - $5,000
# Initial Deposit - $15,000
# Monthly Payments - $3,334
# Note: Buyer can also suggest Payment Plan best for Him/Her but must be within 24 Months
#
# Description
# A Luxury Studio for Sale at Tse-Addo (Near Cantonments & Labone)
# Features:
# Storeroom
# Guest Washroom
# Backup Water Supply
# Rooftop Recreational Area with Sea Views
# Air Conditioning Units
# Fitted Kitchen with Appliances (Cooker Unit, Extractor, Oven, Microwave)
# Smart Home
# Private Parking & a Garden
# 24 Hr CCTV
# Secured Gated Community with 24 Hr security
# Security Post
# Gym
# Communal Swimming Pool
# Flexible Payment Plans
# Construction ongoing
# Completion date is December 2023
# Studio Apartments (35 SQM)
# Payment Plans
# A. 1 year payment plan for $70,000:
# Reservation fee - $5,000
# Initial Deposit - $9,000
# Monthly Payments - $4,667
# B. 2 years payment plan for $70,000:
# Reservation fee - $5,000
# Initial Deposit - $9,000
# Monthly Payments - $2,334
# Note: Buyer can also suggest Payment Plan best for Him/Her but must be within 24 Months
#
# 4 Bedroom House for Sale at East Legon (Trassaco/Adjiringanor)
# Features:
# Communal Rooftop Gym
# Playground
# Storeroom
# Extra Family Area
# Boys Quarters
# Backup Water Supply
# Self Compound Homes
# Air Conditioning Units
# Fitted Kitchen with Appliances (Cooker Unit, Extractor, Oven, Microwave)
# Smart Home
# Each House with Parking for at least 3 Cars & a Garden
# 24 Hr CCTV
# Secured Gated Community with 24 Hr security
# Security Post
# Flexible Payment Plans
# Price is $320,000
# Payment Plans
# One-and-a-half-year payment plan for $320,000:
# Reservation fee - 2%
# 23% Down Payment
# 25% Deposit by 6 Months
# 25% Deposit by 12 Months
# 25% Deposit by 18 Months
# Or
# Reservation fee - 2%
# Down Payment - 28%
# Spread 70% Balance over 18 Months
# Note: Buyer can suggest Payment Plan best for Him/Her but must be within 24 Months
# Appliances
# Wardrobes
# Amenities
# Security Fence
#
# Appliances
# Wardrobes
#
# Amenities
# Garden
#
#
# Description
# 3 Bedroom House for Sale at East Legon (Trassaco/Adjiringanor)
# Features:
# Communal Rooftop Gym
# Playground
# Storeroom
# Extra Family Area
# Boys Quarters
# Backup Water Supply
# Self Compound Homes
# Air Conditioning Units
# Fitted Kitchen with Appliances (Cooker Unit, Extractor, Oven, Microwave)
# Smart Home
# Each House with Parking for at least 3 Cars & a Garden
# 24 Hr CCTV
# Secured Gated Community with 24 Hr security
# Security Post
# Flexible Payment Plans
# Price is $280,000
# Payment Plans
# A. 1 year payment plan for $280,000:
# Reservation fee - $5,000
# Initial Deposit - $51,000
# Monthly Payments - $18,667
#   B. 2 years payment plan for $280,000:
# Reservation fee - $5,000
# Initial Deposit - $51,000
# Monthly Payments - $9,334
#   Note: Buyer can suggest Payment Plan best for Him/Her but must be within 24 Months
# Appliances
# Wardrobes
#
# Appliances
# Wardrobes
#
# 2 Bedroom house going for USD 55,000
# 3 Bedroom house going for USD 60,000
# 4 Bedroom house going for USD 75,000
#
# Appliances
# Wardrobes
#
# Appliances
# Dishwasher
# Water Heater
# Microwave
# Air Condition
# Gas Range
# Electric Cooker
# Washing Machine
# Kitchen extractor
# Wardrobes
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# CCTV
# Water storage and pumping system
# Garage
# Solar Energy
# Parking
#
# Furnished & unfurnished 3 bedrooms houses with staff quarter for sale at East Airport (Tse Addo) & Achimota (Tantra Hills)
# Facilities includes:
# Centralized solar water heaters
# Intercom
# Internet
# Cctv cameras
# Living and Dining Area
# En-Suite Bedrooms
# Large flat screen TV
# Fully air-conditioned
# Automated Gate
# Electric Fence
# Fully fitted Kitchen with Fridge, Stove, Microwave, Washing Machine, etc
# Price Starts From: $300,000
# * Flexible Payment Plan Available
# * Mortgage for up-to 20years Available
# * Additional comprehensive insurance cover for 1year Available.
# Ps: Others may prefer it unfurnished that is why our houses are left unfurnished but if you want it furnished, you are getting exactly as seen in the 3D pictures.
# Contact: 0244811233
#
# This is a 12 bedrooms duplex building of apartments located in Afienya, Mataheko and sit on 4 plots are available on sale. Each duplex is selling for ¢1,157,000.
# Appliances
# Dishwasher
# Water Heater
# Microwave
# Air Condition
# Recess Light
# Washing Machine
# Wardrobes
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# CCTV
# Water storage and pumping system
# Garage
# Swimming Pool
# Generator
# Parking
# Facilities Management Services
# Gym
# Super market
# Pre-paid Meter
# Laundry
# Restaurant
# Conference Hall
#
# Description
# Roman Ridge rests comfortably in the top tier when it comes to prime locations in Ghana's capital city Accra. Located in the northern part of the city, this well planned neighborhood is highly sought after for its convenient location and accessibility to major business, retail and entertainment hubs. Flanked by the elite Airport Residential and Dzorwulu areas, Roman Ridge is perfectly situated in close proximity to the best schools, malls, healthcare, and financial services in Accra. Roman Ridge is undeniably a perfect location for real estate investment in Ghana, with price appreciations translating to profits for property owners that are selling or renting out.
# A mixed-use ultra modern urban lifestyle development, NoVA comes in studios, 1, 2 and 3 bedroom apartments complimented with the convenience and living essentials tenants require; as well as the luxury and freedom they deserve. Whether it’s a relaxing day at the spa, lounging at the bar with friends or spending time with the kids at the play centre, NoVA promises the freedom and choice to do these things and much more. There’s something for every lifestyle. Developed by the 2017/2018 Africa and Arabia Property Awards Winner for the categories “Best Apartment Ghana” and “Best Development Marketing”, and global nomination for “Best Apartment in Africa”, NoVA promises to be yet another true reflection of the quality architecture, elegant aesthetics and upscale signature homes drawn from the many years of experience Devtraco Plus is renowned for.
# Facilities and Services
# Gym
# Rooftop swimming pools
# Meeting facilities
# Lounge
# Courtyard
# Retail and commercial area
# On-site maintenance
# General tenant facilities:
# Parking
# Concierge
# 24/7 security
# Back-up power
# Reservoir water
# Swimming pool
# Landscaped gardens
# Children’s play ground
# Café/Lounge/Restaurants
# Conference centre
# Laundry services
# Unisex hair salon
# Business centre
# Kids’ centre
# ATM centre
# KEY INFORMATION
# 12% rental returns on US Dollar - *Estimated Value
# 5% Capital Gains
# $141,347 Starting Sale Price
# 15 minutes from Kotoka International Airport
# 15 minutes from the Accra Mall
# 20 minutes from the major social and hub Osu
#
# Description
# Devtraco Plus is delighted to offer you the opportunity to invest in deluxe, branded hotel apartments. Through our world-class Pelican Hotel Apartments, you can join a global community of hotel investors, right here in Accra. The first of its kind in Ghana, this is a real estate investment in which the apartment you purchase is leased to our hotel. You generate rental income as we manage the hotel: you simply sit back and watch your investment earn a good return. Comprising of 122 single and double-bedroom apartments, The Pelican’s spacious units are designed to make all our guests feel at home, encouraging them to stay for a prolonged period.
#   Hotel Amenities
# Concierge service
# On-site marketing
# Fitness centre
# Swimming pool
# Bar & Lounge
# On-site restaurant
# Business centre
# Housekeeping
# Proximity (easy access to cultural hotspots)
#   Room Amenities
# Fridge
# Satellite TV
# WiFi
# Kitchenette (fridge, microwave and
# coffee maker)
# Iron and ironing board
# Complimentary toiletries
# Air-conditioning
#   Why Invest In The Pelican
# Fully managed and branded boutique-hotel-style development
# High return potential which can be resold at a premium compared to traditional real estate investments
# Ideal location with proximity to Accra’s prime business districts (Osu, Labone, Ridge,
# Cantonments, Airport)
# Experienced hotel management, high quality standards, good customer service and
# world-class facilities to generate sales and result in high occupancy with strong returns
# Hands-off investment
# Dynamic pricing allows constant adjustment of room rates, encouraging higher
# occupancy in every market condition
# Fully furnished to the highest standards
#   THE PELICAN HOTEL MODEL
# 1 PURCHASE Invest in one or multiple hotel apartments of your choice.
# 2 LEASE BACK Lease your hotel apartment back to The Pelican Hotel while you relax and let us manage your property.
# It is a completely hands-off investment.
# 3 INCOME Your hotel apartment becomes an income-generating asset.
# 4 STRONG POTENTIAL OUTWEIGHS AVERAGE MARKET Accra’s hotel market is very robust, and quality short-, medium- and long-term rentals are in high demand.
# Appliances
# Dishwasher
# Water Heater
# Microwave
# Air Condition
# Washing Machine
# Wardrobes
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# CCTV
# Water storage and pumping system
# Swimming Pool
# Generator
# Parking
# Facilities Management Services
# Gym
# Super market
# Office space
# Pre-paid Meter
# Laundry
# Restaurant
# Conference Hall
#
# Description
# Roman Ridge rests comfortably in the top tier when it comes to prime locations in Ghana's capital city Accra. Located in the northern part of the city, this well planned neighborhood is highly sought after for its convenient location and accessibility to major business, retail and entertainment hubs. Flanked by the elite Airport Residential and Dzorwulu areas, Roman Ridge is perfectly situated in close proximity to the best schools, malls, healthcare, and financial services in Accra. Roman Ridge is undeniably a perfect location for real estate investment in Ghana, with price appreciations translating to profits for property owners that are selling or renting out.
# A mixed-use ultra modern urban lifestyle development, NoVA comes in studios, 1, 2 and 3 bedroom apartments complimented with the convenience and living essentials tenants require; as well as the luxury and freedom they deserve. Whether it’s a relaxing day at the spa, lounging at the bar with friends or spending time with the kids at the play centre, NoVA promises the freedom and choice to do these things and much more. There’s something for every lifestyle. Developed by the 2017/2018 Africa and Arabia Property Awards Winner for the categories “Best Apartment Ghana” and “Best Development Marketing”,and global nomination for “Best Apartment in Africa”, NoVA promises to be yet another true reflection of the quality architecture, elegant aesthetics and upscale signature homes drawn from the many years of experience Devtraco Plus is renowned for.
# Facilities and Services
# Gym
# Rooftop swimming pools
# Meeting facilities
# Lounge
# Courtyard
# Retail and commercial area
# KEY INFORMATION
# 12% rental returns on US Dollar - *Estimated Value
# 5% Capital Gains
# $141,347 Starting Sale Price
# 15 minutes from Kotoka International Airport
# 15 minutes from the Accra Mall
# 20 minutes from the major social and hub Osu
# Appliances
# Water Heater
# Air Condition
# Wardrobes
# Amenities
# 24-hour Security
# Internet Connection
# CCTV
# Water storage and pumping system
# Car Port
# Swimming Pool
# Generator
# Solar Energy
# Parking
# Facilities Management Services
# Gym
# Super market
# Balcony
# Office space
# Laundry
# Restaurant
# Conference Hall
#
# Fitted Kitchen
# Appliances
# Water Heater
# Air Condition
# Wardrobes
# Amenities
# 24-hour Security
# Internet Connection
# Water storage and pumping system
# Garage
# Car Port
# Swimming Pool
# Generator
# Solar Energy
# Parking
# Facilities Management Services
# Gym
# Super market
# Balcony
# Office space
# Pre-paid Meter
# Garden
# Laundry
# Restaurant
# Conference Hall
#
# Fitted Kitchen
#
# Harmonia Residence is a 16-story mix-use residential apartment located strategically at West Airport, It is made up of studios, 1,2,3 bedroom with a penthouse, and a sky-villa.
# Harmonia is mapped out to make you feel connected and offers you the needed personal space. We are not just offering you an address but also an investment you can be proud of with Better ROI.
# At Harmonia Residence, we made sure to include all the required facilities and more to maintain the luxurious life you deserve. This beautiful development is strategically positioned to give you asses to other amenities.
# Harmonia residence is also designed to have a mini-market, Pharmacy, Restaurant, Spa, Gym, Sky Launch Meeting Rooms and a kids' play area.
# With a competitive market price, I am proud to inform you that the project is 75% sold out.
#
#
# Harmonia Residence is a 16-story mix-use residential apartment located strategically at West Airport, It is made up of studios, 1,2,3 bedroom with a penthouse, and a sky-villa.
# Harmonia is mapped out to make you feel connected and offers you the needed personal space. We are not just offering you an address but also an investment you can be proud of with Better ROI.
# At Harmonia Residence, we made sure to include all the required facilities and more to maintain the luxurious life you deserve. This beautiful development is strategically positioned to give you asses to other amenities.
# Harmonia residence is also designed to have a mini-market, Pharmacy, Restaurant, Spa, Gym, Sky Launch Meeting Rooms and a kids' play area.
# With a competitive market price, I am proud to inform you that the project is 75% sold out.
#
# Appliances
# Dishwasher
# Water Heater
# Kitchen extractor
# Wardrobes
# Amenities
# Security Fence
# 24-hour Security
# Water storage and pumping system
# Garage
# Car Port
# Swimming Pool
# Parking
# Balcony
# Pre-paid Meter
# Laundry
#
# This is a newly constructed 4 bedroom residential property with swimming pool located in Kumasi, Ahenema Kokoben. The land is measured 7000sqft and comes with allocation note and site plan. It is a very serene and secured environment.
#
# Appliances
# Microwave
# Air Condition
# Recess Light
# Electric Cooker
# Washing Machine
# Kitchen extractor
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# CCTV
# Water storage and pumping system
# Swimming Pool
# Generator
# Facilities Management Services
# Gym
# Balcony
# Pre-paid Meter
# Garden
# Laundry
# Restaurant
# Conference Hall
#
# JUST LISTED ??????
# An exceptional Garden Square community designed around the wellbeing of residents, this landmark development offers communal gardens, 3 swimming pools and a dual-storey Wellness Complex. With impeccable new build quality and stellar resident amenities,  offers a rare and covetable blend of style, comfort and location.
# Only 3 UNITS AVAILABLE
# 2 BEDROOM DUPLEX
# FEATURES &AMENITIES????
# 3 Swimming Pools
# Gym and Yoga Studio
# Café
# Reception
# Underground Parking
# Lifts
# 24 Hour Security and CCTV
# 24 Hour FM Hotline
# Back Up Utilities
# STARTING PRICE:$271,950/ CEDI EQUIVALENT
# ??0550678148
# SCHEDULE AN APPOINTMENT FOR VIEWING
# #forsale#duplex#buytolet #luxury #executivehousesghana
# Appliances
# Water Heater
# Microwave
# Air Condition
# Electric Cooker
# Washing Machine
# Kitchen extractor
# Wardrobes
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# CCTV
# Water storage and pumping system
# Car Port
# Generator
# Parking
# Facilities Management Services
# Gym
# Super market
# Balcony
# Office space
# Clubhouse
# Garden
# Laundry
# Restaurant
# Conference Hall
#
# JUST LISTED SELLING NOW????? SPECIFICATIONS
# 2 BEDROOM
# 2 BATHROOMS
# 72SQM
# SELLING PRICE:$245,000USD
# AMENITIES
# GYM
# SWIMMING POOL
# UNDERGROUND PARKING
# BACK UP PRESSURISED WATER
# HIGH SPEED BROADBAND
# CONNECTION
# DSTV CONNECTION
# 24 HOUR SECURITY
# STRONG RENTAL DEMAND
# BACK UP GENERATOR
# CONCIERGE
#
# FLOOR GROUNG FLOOR
# ONLY 1 UNIT AVAILABLE NOW
# BOOK YOUR INTEREST
# CALL US NOW
# 0550678148
# Appliances
# Water Heater
# Microwave
# Air Condition
# Recess Light
# Gas Range
# Electric Cooker
# Washing Machine
# Kitchen extractor
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# CCTV
# Water storage and pumping system
# Swimming Pool
# Generator
# Solar Energy
# Parking
# Facilities Management Services
# Gym
# Super market
# Balcony
# Office space
# Pre-paid Meter
# Clubhouse
# Garden
# Laundry
# Restaurant
# Conference Hall
#
# SELLING NOW
# AVAILABLE UNITS
# STUDIOS
# 1 BEDROOM
# 2 BEDROOM
# 3BEDROOM
# UNIT TYPE ,        PRICE               SIZE SQM
# STUDIO        $118,0000USD              38.29
# STUDIO        $147,0000USD               48.58
# STUDIO        $139,000USD                 45.96
# 1 BED           $147,000USD                 48.58
# 1 BED +DEN  $222,000USD                74.3
# 1 BED             $ 147,000USD              48.58
# 2 BED             $ 303,000USD                 98
# 3 BED             $394,000USD              129.3
# FEW UNITS AVAILABLE NOW????
# AMENITIES &FIXTURES ??????
# POOL
# GYM
# LOUNGE
# COUNTYYARD
# RETAIL AND COMMERCIAL AREA
# BENEFITS OF OWNING A UNIT????
# 12% RENTAL RETURNS
# 5%CAPITAL GAINS
# 15 MINUTES FROM KOTOKA
# 15 MINUTES FROM THE ACCRA MALL
# 20 MINUTES FROM MAJOR SOCIAL HUBS
# STARTING PRICE:$141,347USD CEDI
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# CCTV
# Water storage and pumping system
# Facilities Management Services
# Balcony
# Pre-paid Meter
# Clubhouse
#
# BEDROOM ENSUITE SEMI DETACHED STOREY BUILDINGS AT AYI MENSAH, ACCRA
# House type: *3 bedroom detached Storey building*
# Location : ?
# *OYARIFA
# Features:
# ? All bedrooms are atop
# ? Bedrooms have fitted aircondition - (optional)
# ? All bedrooms are ensuite
# ? Hall + Dining area below
# ? Aircondotion at hall (optional)
# ? Kitchen fitted with cabinets
# ? Store room below
# ? 1 visitor's toilet below
# ? Tiled compound
# ? Complete POP ceiling
# ? Centralised water supply
# ? Over head Polytank stand
# *US $ 200,000 dollars at OYARIFA* (gated community)
# CALL OR WHATAPP ??0550678148
# BOOK YOUR VIEWING APPOINTMENT
# VIA LINK ON BIO ?
#
# 85% UNCOMPLETED
# 3 BEDROOMS
# 4 WASH ROOMS
# DINING AREA
# PLOT SIZE 35X60FT
# LOC ABOKOBI AREA
# DOC TITLE
# PRICE GH300,000
#
#
# 3 bedroom house for sale at old Ashongman (Pure water)
# Asking price : Ghc750, 000 negotiable
# All rooms ensuit
# 3 bedrooms
# Fitted kitchen
# Spacecious living room
#
# Appliances
# Water Heater
# Microwave
# Air Condition
# Recess Light
# Gas Range
# Kitchen extractor
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# Water storage and pumping system
# Parking
# Facilities Management Services
# Balcony
# Pre-paid Meter
#
# JUST LISTED ????????
# 4BEDROOM|| 4BATHROOM LUXURY TOWNHOUSES
# AMENITIES &FIXTURES????
# Premium appliances (Bosch)
# All rooms en-suite
# Fitted kitchen
# Landscape layout
# Modern design with top notch finishing
# PAYMENT PLAN AVAILABLE
# ?60% Down payment40%  spread rest within 12 months
# ?Mortage available
# ?EASTLEGON HILLS??.
# FOR ENQUIRIES AND BOOKINGS
# ??+233550678148
# ? executivehousesgh@gmail.com
# Appliances
# Air Condition
# Recess Light
# Kitchen extractor
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# Water storage and pumping system
# Parking
# Pre-paid Meter
#
# JUST LISTED ?????
# 4 bedrooms house
# all rooms en-suite
# Fitted kitchen
# Walled and gated
# ?tema community 25
#  Documentation:Titled
# Price $70,000 CEDI EQUIVALENT
# FOR ENQUIRIES AND VIEWING ??+233550678148
# Listed by @iamgloriaosei
#
# Executive 3 bedroom house for  sale at East legon hill
#
# *Listing:1296*
#  *SALE:2/3BDR HSE@ OYARIFA*
# ULTRA MODERN 2-3 BEDROOMS DUPLEX HOUSE
# -SPACIOUS COMPOUND
# -FENCED & GATED
# -CCTV CAMERAS FIX
# -TILED COMPOUND
# -MODERN FITTED -KITCHEN
# -BURNER
# -MICROWAVE
# -BUGLAR PROOF WINDOWS
# -BUGLAR PROOF DOORS
# -SPACIOUS BEDROOMS
# -ALL BEDROOMS ENSUITE
# -GUEST WASH ROOM
# -P.O.P CEILING
# -WATER AVAILABLE
# -ELECTRICITY AVAILABLE
# -LOC FOCUS HOSPITAL OYARIFA
# -DOC LAND TITILE
# -PRICE GH900,000 2 BEDROOMS
#  GH1,000,000 3 BEDROOMS
#
#
# *Listing: 903*
#  *SALE 4BDR HSE@ BOTWE LAKESIDE*
# Executive 4 Bedroom house plus boyquarter up for sale at botwe lakeside Community
# Price,: *$200,000 negotiatiable*
#
#
# HOUSE FOR SALE
# LOCATION: East Legon Hills, Near British International School.
# Description
# Consists of 4 bedrooms and a boys quarters making 5 bedrooms. This property comes with provision for a swimming pool and is situated on 45/110 plot size.
# All bedrooms en-suite with one guest washroom for servant quarters and one for guests indoors.
# Specifications
# CCTV Camera
# Reservoir
# Ample Parking Space
# Fitted Kitchen
# Gas Burner
# Heat Extractor
# Controlled Water Pressure
# Fountain
# 1 Kitchen with Store Room
# Air Conditioner
# Microwave
# Fitted Wardrobe
# Electric Fence
# Provision for swimming pool
# Fridge
# Price: $350,000 negotiable
#
# Appliances
# Air Condition
# Recess Light
# Gas Range
# Kitchen extractor
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# Water storage and pumping system
# Parking
# Pre-paid Meter
#
# JUST LISTED ?????
# 4 bedrooms house
# all rooms en-suite
# Fitted kitchen
# Walled and gated
# ?tema community 25
#  Documentation:Titled
#
# Price $70,000 CEDI EQUIVALENT
# FOR ENQUIRIES AND VIEWING ??+233550678148
# Listed by @iamgloriaosei
#
#
# Executive newly built 3 bedroom townhouse up for rent located at anasaman
#   $130,000
#
# For Sale
# EXECUTIVE 6-BEDROOM HOUSE WITH A SWIMMING POOL IS NOW AVAILABLE FOR SALE @ EAST AIRPORT NEAR GHANA INTERNATIONAL MALL
# Price-$650,000 USD
# Descriptions:
# This 6-bedroom self compound house with a swimming pool is available for sale in a gated community at East Airport
# Amenities/facilities:
# 1.Five bedroom house
# 2.Gated community
# 3.Air conditioning
# 4.Six washrooms
# 5.Remote controlled garage
# 6.Fitted kitchen with appliances
# 7.Two bedroom boys quarters
# 8.Swimming pool
# 9.Paved compound
# 10.Security post
# 11.Close proximity to all essential services such as diplomatic missions,governmental institutions,health services,education services etc……
# Appliances
# Microwave
# Air Condition
# Gas Range
# Kitchen extractor
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# CCTV
# Parking
# Facilities Management Services
# Pre-paid Meter
# Garden
#
# 3 bedroom semidetached ($140k)
# -Open plan living and dining area
# -Kitchen with cabinetry
# -Ensuite master bedroom
# -Two additional bedrooms with shared bathroom
# -Two parking spaces
# -Private backyard space
# Appliances
# Water Heater
# Microwave
# Air Condition
# Recess Light
# Gas Range
# Electric Cooker
# Washing Machine
# Kitchen extractor
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# CCTV
# Water storage and pumping system
# Garage
# Car Port
# Swimming Pool
# Generator
# Parking
# Facilities Management Services
# Gym
# Super market
# Balcony
# Office space
# Pre-paid Meter
# Clubhouse
# Garden
# Laundry
# Restaurant
# Conference Hall
#
# JUST LISTED ???
#  Selling Now offplan  serviced apartment studio,1&2 bedroom
# Units details ??
# Listed by @iamgloriaosei
# Executive studio type A
# Executive studio type B
# 1 bedroom type A
# 1 bedroom type B
# 2 bedroom  type A
# 2 bedroom type B
# Starting Prices
# $95,950 USD (Studio )
# $118,950USD (1 BEDROOM)
# $234,950USD (2 BEDROOMS)
# FEATURES AND SPECIFICATIONS ??
# Private residence garden
# Rooftop swimming pool
# Gymnasium
# High quality appliances
# Car charging point
# Air conditioning
# 10 years build warranty (structural)
# Mix of Executive studio suite 1 and 2 bedroom apartment
# Estimated completion Q2 2026
# Appliances
# Water Heater
# Microwave
# Air Condition
# Kitchen extractor
# Wardrobes
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# CCTV
# Parking
# Facilities Management Services
# Balcony
# Pre-paid Meter
# Garden
#
# LOCATION - East  Legon (Trassaco / Adjiringanor)
# Features -
# -Communal Rooftop Gym
# -Playground
# -Storeroom
# -Extra Family Area
# -Boys Quarters
# -Backup Water Supply
# -Self Compound Homes
# -Air Conditioning Units
# -Fitted Kitchen with Appliances (Cooker Unit, Extractor, Oven, Microwave)
# -Smart Home
# -Each House with Parking for at least 3 Cars & a Garden
# -24 Hr CCTV
# -Secured Gated Community with 24 Hr security
# -Security Post
# -Flexible Payment Plans
#
# 3 Bedrooms
#   Buyer can also suggest Payment Plan best for Him/Her but must be within 24 Months
# ------------------
# Mortgage:
# 20% to 30% down payment
# Mortgage pays the rest
# Appliances
# Air Condition
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# Water storage and pumping system
# Parking
# Balcony
# Pre-paid Meter
#
# All rooms ensuite
# Fitted kitchen
# Spacious compound
# Secured environment
# Appliances
# Water Heater
# Microwave
# Air Condition
# Kitchen extractor
# Wardrobes
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# Garage
# Swimming Pool
# Parking
# Balcony
# Pre-paid Meter
# Garden
#
# bedroom house with a swimming pool is up for sale around ARS round-about
# Pool
# Landscape
# Fitted kitchen
# Garden
# Landscape
# Serene environment
# Spacious compound
# Appliances
# Gas Range
# Kitchen extractor
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# Water storage and pumping system
# Pre-paid Meter
#
# Ex 3 bedroom trophy house for at lakeside estate
# Triple A location
# Easy access
# Spacious rooms
# Neat washrooms
# Fitted kicthen
# All electrical fittings done
# Ghana water available
# Wall and gated community
# Great master piece
# Asking price 110,000 $ negotiable
# Appliances
# Water Heater
# Microwave
# Air Condition
# Gas Range
# Washing Machine
# Kitchen extractor
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# CCTV
# Water storage and pumping system
# Generator
# Parking
# Facilities Management Services
# Balcony
# Pre-paid Meter
#
# Designed with top notch features offering the best stay and high profit on investment for homeowners and property investors this 3 bedroom apartment offers an impeccable amenites to make your stay peaceful book your viewing appointment with us now
# Appliances
# Water Heater
# Microwave
# Air Condition
# Gas Range
# Electric Cooker
# Washing Machine
# Kitchen extractor
# Wardrobes
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# Water storage and pumping system
# Garage
# Swimming Pool
# Parking
# Balcony
# Office space
# Pre-paid Meter
#
# Appliances
# Water Heater
# Microwave
# Air Condition
# Recess Light
# Gas Range
# Electric Cooker
# Kitchen extractor
# Wardrobes
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# CCTV
# Water storage and pumping system
# Garage
# Car Port
# Swimming Pool
# Generator
# Parking
# Facilities Management Services
# Gym
# Super market
# Balcony
# Office space
# Pre-paid Meter
# Clubhouse
# Garden
# Conference Hall
#
# SELlING NOW UNITS AVAILABLE ??
# with this philosophy at heart. The layout of the development optimises the potential for green space within the urban environment, maintaining car-free outside areas and allowing scope for generous horticulture. Intentional use of glass and thoroughfares enables the visual impact of these green spaces to positively enhance interior spaces too.
# With a gym space, pool and relaxation terrace and communal gardens,  offers space for residents to recharge and step out into the city feeling focused and restored.
# Beyond facilities and services, small design details can also improve the quality of everyday life (often imperceptibly). From corridor acoustics, to the layout of kitchen
# BUY TO LET
# Pool
# Gym
# Communal Gardens
# Rooftop Lounges
# Reception
# 24 Hour Security
# LET
# Pool
# Gym
# Communal Gardens
# Rooftop Lounges
# Reception
# 24 Hour Security
# Access Control
# 24 Hour FM Hotline
# Back-up Utilities
# Café
# Serviced Option
# DSTV
# Internet Access
# Laundry and Cleaning
# 24 Hour FM Hotline
# Gym Access
# Swimming Pool
# Underground Parking
# ENQUIRIES AND DETAILS ??0550678148
# EMAIL:EXECUTIVEHOUSESGH@GMAIL.COM
# Amenities
# Security Fence
# 24-hour Security
# Water storage and pumping system
# Parking
# Facilities Management Services
# Pre-paid Meter
# Garden
# Laundry
#
# Appliances
# Water Heater
# Microwave
# Air Condition
# Electric Cooker
# Washing Machine
# Kitchen extractor
# Wardrobes
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# Water storage and pumping system
# Parking
# Facilities Management Services
# Balcony
# Pre-paid Meter
#
# LISTED ??
# gated community of 3 bedroom detached two storey units located Tema Community 25.
# [Interior]
# All rooms en-suite
# Fitted kitchen cabinetry with appliances
# Burglar proof on all windows
# Ceramic floor tiles
# Italian wall tiles
# Fitted wardrobes in all rooms
# P.O.P ceiling
# British quality sanitary fittings
# Pure wood panel and flash internal doors
#   [ Exterior ]
# Double pergola car port
# Water tank and pump provided in each house
# CCTV camera infused street lighting
# Paved compounds with beautiful landscape
# Pergola roofed terrace on top floor
# Architectural Roof shingles
# Security doors and locks for all external doors
# [General area]
# 24/7 estate management service
# Paved and landscaped drive and walk ways
# Communal area:  pool; playground; outdoor
# Follow us @executivehousesghana
# DM,WHATAPP OR CALL
# BOOK YOUR INTEREST
# CONTACT ??+233550678148
# EMAIL:EXECUTIVEHOUSESGH@GMAIL.COM
# Appliances
# Water Heater
# Microwave
# Air Condition
# Electric Cooker
# Kitchen extractor
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# CCTV
# Water storage and pumping system
# Facilities Management Services
# Pre-paid Meter
#
# 3 bedroom all ensuite with a boys quarters.
# Located at North Legon. 10 minutes drive from The University of Ghana
# $242,000
# It's a smart home.
# Fitted Kitchen.
# Air conditioners,
# Remote gate.
# CCTV Cameras.
# Estate Management.
# 24hrs security
# Appliances
# Water Heater
# Microwave
# Air Condition
# Kitchen extractor
# Wardrobes
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# Water storage and pumping system
# Swimming Pool
# Parking
# Balcony
# Pre-paid Meter
#
# Every surface, every space, and every mome is designed and decorated with passion??
# ?With ???????? ????????, ????????? ??????? ?????, ????-??? ?????????, takes indoor-outdoor living to all-new realms.
# ?? 3 bedrooms, 1 boys' quarters
# ?? Fully-furnished
# ?? Spacious sitting room area
# ?? High-end amenties
# ?? Oversized parking area
# ?? Swimming pool
# ?East Legon hills more than a home. It's your very own personal resort.
# Appliances
# Dishwasher
# Water Heater
# Microwave
# Air Condition
# Recess Light
# Electric Cooker
# Kitchen extractor
# Wardrobes
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# Water storage and pumping system
# Parking
# Pre-paid Meter
# Garden
#
# LUXURY 3.5 BEDROOM HOUSE WITHIN A PRIME AREA IN TSEADDO
# WITH UNIQUE FEATURES AND TOP NOTCH INTERIOR UNIT COMES IN FURNISHED AND UNFINISHED
# Appliances
# Water Heater
# Microwave
# Air Condition
# Electric Cooker
# Kitchen extractor
# Wardrobes
# Amenities
# Security Fence
# 24-hour Security
# Car Port
# Swimming Pool
# Parking
# Balcony
# Pre-paid Meter
#
# Luxury 4 bedroom with boys quarters and pool with unique features like lounge and a sunken lounge a washroom and a toilet outside for the pool area
# land size is 45x109 feet
# Compound takes 4 SUVs cars or more for saloons cars. Master bedroom and it closet is 77m2 and all the rooms are en-suite
#
# Executive newly built 4 bedroom house plus extra boyquarters up for sale at East legon Shiashie
#
# 2bedroom for sale at Santo price is going for $60 000 dollars negotiable
# ???
#
# *Listing:1294*
#  *SALE:3BDR HSE@ SAKUMONO*
# Three bedrooms self compound house in a serene environment of Sakumono properly tarred road
# Going for Sale at $ *$160,000*
#
#
# *Listing:1365*
#  *SALE: 4BDR HSE@ OYARIFA SPECIAL*
# Executive Newly built 4 Bedroom detached house up for sale on a registered 50/100ft plot of land located at oyarifa special ice area
# Price: *Ghc 1.6 million*
#
#
# 3 bedrooms house for sale at Lashibi com 20  Cambodia, it has a dinning area and a spacious hall
# All en-suite with visitors washroom
# Biogas in use
# Plot size: 60/100
# It has been used for one year six months
# Slightly used
# Ghc1.000.000( Ghc1 million
# ???
#
# *Listing:902*
#  *SALE:4BDR HSE@ EL*
# Executive 4 bedroom house plus a boy quarter come with swimming pool and other facilities for sale at east legon
# Price: *$600,000*
#
#
# *Listing:1079*
#  *SALE: 4BDR HSE@TSEADDO*
# ? HOUSE FOR SALE
# Standard 4-Bedroom House for sale located at TSEADDO, Accra Ghana
# Ongoing development
# All rooms En-Suits bedrooms in secure environment
# Master bedroom has a walk-in-closet
# Fully fitted kitchen
# Price *USD $420,000*
#
# Appliances
# Water Heater
# Recess Light
# Gas Range
# Wardrobes
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# CCTV
# Water storage and pumping system
# Car Port
# Parking
# Balcony
# Pre-paid Meter
#
# 4 bedrooms house with 5 washrooms storey at OYARIFA…Patang village
# **Property has land Title Certificate with 95years lease. Price is GHC 1,550,000
# contact 0242539127.
# #houseforsale #realestateagent #realestate #propertyforsale #propertyzonegh
#
# *Listing:1398*
#  *SALE:4BDR HSE@ KWABENYA ACP*
# Newly built 4 bedroom house for sale
# Location : kwabenya Acp
# Price : GH? 2,400,000 negotiable
# Details
# 4 bedroom executive house
# Study room /office
# Water Heater in all rooms
# AC in all rooms
# Fitted kitchen
# Electric fence
# Running water
# Automated gate system
#
# HOUSE FOR SALE
# LOCATION: East Legon Hills, Near British International School.
# Description
# Consists of 4 bedrooms and a boys quarters making 5 bedrooms. This property comes with provision for a swimming pool and is situated on 45/110 plot size.
# All bedrooms en-suite with one guest washroom for servant quarters and one for guests indoors.
# Specifications
# CCTV Camera
# Reservoir
# Ample Parking Space
# Fitted Kitchen
# Gas Burner
# Heat Extractor
# Controlled Water Pressure
# Fountain
# 1 Kitchen with Store Room
# Air Conditioner
# Microwave
# Fitted Wardrobe
# Electric Fence
# Provision for swimming pool
# Fridge
# Price: $350,000 negotiable
# Agency terms and conditions are Applied
#
#
# *Listing:1391*
#  :5BDR HSE@ ROMAN RIDGE*
# A newly-built five bedroom house self compound going for sale at Roman ridge price $680000 negotiable
# ???
#
# *Listing:1381*
#  *SALE:3BDR HSE@ OSU NYANIBA ESTATE*
# 3 bedrooms with 2 bedrooms boy's at the nyaniba estates selling for $450,000 slightly negotiable
#
# *Listing:1388*
#  *Sale:5BDR HSE@ AIRPORT HILL*
# 5BEDROOM WITH 3BOYS QUARTERS AT AIRPORT HILLS  FOR SALE ON A 2PLOT OF LAND
# PRICE.    $2M
#
#
# *3 bedroom town-house forsale @ Oyarifar-Special*
# *Selling price $150,000 negotiable*
# *Facility:*
# 1 servant quarters
# All en-suites rooms
# Fitted kitchen
# Fixed Acs & Fans
# 24hrs security service
# Land Title Certificate
#
# *Listing:1311*
#  *SALE:4BDR TWNHSE@ ASHALLEY BOTWE*
# Ultra modern 4 Bedroom townhouse up for sale at ashalley botwe going for
# Price: *$300,000*
# ???
#
# *3 bedroom detached house forsale @ Oyarifar*
# *Asking price $190,000 negotiable*
# *Facility:*
# 1 servant quarters
# All en-suites rooms
# Guests washroom
# Fitted kitchen
# Fixed Acs & Fans
# Security barb wires
# 50ft by 100ft plot size
# Land Title Certificate ?
#
#
# *Listing:877*
#  *SALE:3BDR HSE@ HATSO*
# An ultra modern newly built 3 bedroom house plus extra one bedroom boyquarter up for sale at Haatso
# Plot size: 0.2acres
# Doc: Land Titled
# Price: *$190,000*
#  *Amenities*
# -- Ensuite rooms
# -- Modern furnished kitchen
# -- Security post
# -- Install AC
# -- Wardrobe
# -- Remote gate
#
#
# *Listing:1046*
#  *SALE:4BDR HSE@ TANTRA HILL*
# A newly built modern 4bedroom self compound house for sale .
# All rooms are en-suite.
#  A modern and well equipped kitchen.
# Location: At the  heart of Tantra Hills.
# Land size: 32×100 feet.
# Price: 275,000 USD
# Agency term and condition Apply
#
# *3 bedroom town-house forsale @ Oyarifar-Special*
# *Selling price $150,000 negotiable*
# *Facility:*
# 1 servant quarters
# All en-suites rooms
# Fitted kitchen
# Fixed Acs & Fans
# 24hrs security service
# Land Title Certificate ?
#
# *Commercial/Residential Property To-Let:*
# *5 bedroom full house forsale @ Eastlegon*
# *Selling price $550,000 negotiable*
# *Facility:*
# 1 servant quarters
# All en-suites rooms
# Guests washroom
# Security post
# Parking space
# Fitted kitchen
# Fixed Acs & Fans
# Land Title Certificate
#
# *Listing:1389*
#  *SALE 4BDR HSE@ LASHIBI*
# *REGISTERED 4  BEDROOM STOREY HOUSE come with 4 wasro LOCATED AT GATED COMMUNITY NEAR LASHIBI FUNERAL HOME
# **  Built in Wardrobes & Fitted Kitchen Cabinets
# ** Spacious rooms fully tiled
# **  POP ceiling
# **  Plot size is 70 feet by 50 feet (tiled compound)
# Price *: $270,000 negotiable*
#
# Appliances
# Dishwasher
# Water Heater
# Microwave
# Air Condition
# Recess Light
# Electric Cooker
# Kitchen extractor
# Wardrobes
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# Water storage and pumping system
# Garage
# Swimming Pool
# Parking
# Facilities Management Services
# Gym
# Super market
# Pre-paid Meter
# Clubhouse
# Garden
#
# About Johannas Court
# Johanna’s court is a thoughtfully well-planned gated community that comes with a communal swimming pool, gym, playground, solar streetlights and constant supply of water.
# It’s a 3 &4 Bedrooms all en-suite, with air conditioners, a fully fitted kitchen, walk in closest, efficient estate management service and 24-hour security.
# Johanna’s Court is the latest address within the fast growing Katamanso node and portfolio of exclusive residential offerings.
# With private gardens and ample space to relax and entertain, state-of-the-art security and luxurious contemporary finishes, Johanna’s Court offers 14 exclusive homes ensure that balancing work and life in the city is never a compromise.
# Design Features:
# Open floor plan, Fully fitted kitchen with and modern appliances, Engineered stone countertops, Master bedroom suite with dual vanities, Spacious closets, Air Conditioned bedrooms and Living area Ground level guest bedroom suite with full bath, Front Porch, Paved double-car parking space, UPVC glass windows, State-of-the-art security, Pergola Car Park Expanded backyard & Private Garden
# Number of Units available: 8 Units
# Prices:
# a) 3 Bedroom & 3 Bathroom is $140,000
# b) 3 Bedroom & 3.5 Bathroom is $150,000
# c) 4 Bedroom & 3.5 Bathroom is $200,000
#
# Appliances
# Dishwasher
# Water Heater
# Microwave
# Air Condition
# Recess Light
# Electric Cooker
# Kitchen extractor
# Wardrobes
# Amenities
# Security Fence
# 24-hour Security
# Internet Connection
# Water storage and pumping system
# Garage
# Swimming Pool
# Parking
# Facilities Management Services
# Gym
# Super market
# Pre-paid Meter
# Clubhouse
# Garden
#
# About Johannas Court
# Johanna’s court is a thoughtfully well-planned gated community that comes with a communal swimming pool, gym, playground, solar streetlights and constant supply of water.
# It’s a 3 &4 Bedrooms all en-suite, with air conditioners, a fully fitted kitchen, walk in closest, efficient estate management service and 24-hour security.
# Johanna’s Court is the latest address within the fast growing Katamanso node and portfolio of exclusive residential offerings.
# With private gardens and ample space to relax and entertain, state-of-the-art security and luxurious contemporary finishes, Johanna’s Court offers 14 exclusive homes ensure that balancing work and life in the city is never a compromise.
# Design Features:
# Open floor plan, Fully fitted kitchen with and modern appliances, Engineered stone countertops, Master bedroom suite with dual vanities, Spacious closets, Air Conditioned bedrooms and Living area Ground level guest bedroom suite with full bath, Front Porch, Paved double-car parking space, UPVC glass windows, State-of-the-art security, Pergola Car Park Expanded backyard & Private Garden
# Number of Units available: 8 Units
# Prices:
# a) 3 Bedroom & 3 Bathroom is $140,000
# b) 3 Bedroom & 3.5 Bathroom is $150,000
# c) 4 Bedroom & 3.5 Bathroom is $200,000
# Appliances
# Dishwasher
# Microwave
# Air Condition
# Recess Light
# Gas Range
# Electric Cooker
# Wardrobes
# Amenities
# Security Fence
# 24-hour Security
# Water storage and pumping system
# Parking
# Balcony
# Office space
# Pre-paid Meter
#
# About Araba’s Court
# This beautiful home redefines townhouses with a synergy that flows between all levels and fills it with a unique aura of warmth, wellbeing and hospitality.
# Love entertaining? The ARABA’S Court townhouse was designed to make it easy for you. Light, open space, clever design and careful proportions come together seamlessly to create a special connection between the expansive living areas on each floor.
# There’s plenty of space for letting your imagination run free and make your home feel like a tropical resort every- one wants to holiday in! There is ample space for you to have a private pool if you wish. Each townhouse has four generous Bedrooms, including a resort-style Master Suite.
# The inclusion of a Home Theatre on the second floor provides extra space to unwind at the end of the day, while the expansive Gourmet Kitchen is an inviting place for everyone to gather, laugh and forge memories you’ll treasure forever.
# ARABA’S Court will constantly surprise you with the clever little details that enhance the way you live here. The discreet Home Office on the first floor makes it easy to duck away when work calls, while upstairs on the rooftop terrace is a place for retreat.
# The kids will love it too, with a cleverly positioned Study Nook providing the perfect place for homework, and the Children’s Activity room off the upstairs landing giving them their own space to kick back and relax.
# Flawlessly appointed, ARABA’S Court offers a luxurious lifestyle that’s perfect for the discerning homeowner.
# Araba’s Court incorporates clean lines, modern textures and natural light to create distinct living spaces that complement the art of living well.
# This designer residential development is located in a secure, boomed off neighbourhood and comprises 6 private homes with walled gardens and covered patios.
#   Neighboring social amenities:
# ...
# All bedrooms ensuite house
# Guest washroom
# Big hall with dining area
# Kitchen fittted with cabinets
# Water heaters
# Wardrobes
# Water polytank
# Security fence
# Air-conditioning
# Fans
# 24/7 Ghana water
# Price is GHS880,000
# Contact Darwin Agency on 0240098876 if interested
# Appliances
# Air Condition
# Washing Machine
# Amenities
# Security Fence
# Parking
#
# EXECUTIVE 3BEDROOM FULLY FURNISHED WITH 1BEDROOM STAFF QUARTERS HOUSE FOR SALE AT EAST AIRPORT BURMA HILLS â– â– â–
# FEATURES:
# PARTLY PAVED COMPOUND LAWN , LAND DIMENSION 50X80FT, FULLY FITTED KITCHENETTE WITH CABINET AND STORE ROOM, STOVE, GOOD ROAD ACCESS, SPOT LIGHTS, WASHING MACHINE.
#  ALL ROOMS EN-SUITE , ALL ROOMS ARE AIR CONDITIONED, ELECTRIC FENCE, WATER HEATERS, DINING AREA, QUALITY FINISHING WORK
# PRICE $450,000
#
#
# 3BEDROOM HOUSE FOR SALE
# Location : Oyarifa around Mr Smith Hotel
# Price : GHS600,000
# -3Brdroom All en-suite
# -Guest washroom
# -Modern fitted kitchen
# -Store room
# -POP Ceiling
# - Buglar proof windows
# -Air conditioners installed
# -Guest washroom
# -Burglar proof windows
#
# Newly built 5 bedrooms house for sale @  Ashongman Estates on 2 plots of land.
# All bedrooms en-suite. Fitted kitchen
# Swimming pool
# Security fence
# Cctv Security System
# Bar
# Staff quarters
# Price is GHS1,840,000
#
# Amenities
# Security Fence
#
# Features
# -All rooms en suite
# -Study area
# -Personal office space
# -Visitors washroom
# -Spacious hall with dining area
# -2 kitchens ( 1 fitted) with store room
# -Automated Gate
# -Security doors
# -POP ceiling
# -Burglar proof
# -Ample parking space
# - walk in Closet
# - Tools Room
# - Laundry Room
# - Backup Solar Powered
# - Electric Fence Security
# - Outter Gas Cylinder Cage
# - Two Poly tanks
# - Tiled Compound
# - Cctv Connections
# - Pergola with Astro Turf porch
#
# 2 units of 5 bedroom semi detached house for sale at Comm 18
# 5 bedrooms on each side
# All rooms en suite
# The ground floor has a spacious living and dinning area, a kitchen, storeroom and one bedroom.
# The top floor has 4 rooms and a family area.
# All pipes have been layed and provisions for wiring has been made
# The structure is in good condition with no cracks.
#
# 8 bedroom house for sale at Bortianor
# -8 bedrooms
# -2 kitchens
# -2 large halls with dinning area
# -Pop ceiling
# -Security doors
# -Balcony with hill top view
# -Sliding windows
# -Tiled floor
# -Borehole with 4 water reservoir
# -Extra land 50x100FT
# -Serene and secure environment
# -Proximity to tarred road
#
# LAND TITLE AVAILABLE.
# PRICE:$160,000 Negotiable
#
#
# Total land area: 1 Acre
# Storage, Administrative and housing building
# Security room
# 2000sqm warehouse
# 600sqm Office and residential space comprising of 3 floors
# 1st floor: Office space including 3 large offices and 2 bathrooms
# 2nd Floor and 3rd Floor : Residential apartment including 3 master bedroom with living , dinning space , Kitchen and additional guest bathroom
# Amenities
# Security Fence
# CCTV
# Swimming Pool
# Parking
# Gym
# Super market
# Balcony
# Office space
#
# WE ARE GIVING YOU 3YRS PAYMENT PLAN.
# 2BEDROOM STARTING PRICE
# ($211,125USD-75sqm-sq/ft807).
# ($225,345USD-83sqm-sq/ft893).
# ($255,210USD-94sqm-sq/ft1012).
# ($288,500USD-109sqm-sq/ft1173)
#
# GYM.
# OFFICE SPACE.
# SUPER MARKET AREA.
# SWIMMING POOL AREA.
# CONFERENCE HALL AREA.
#
# FULLY FITTED KITCHEN WITH CABINET AND APPLIANCES.
# BALCONY SPACE WITH GREAT VIEW.
# CCTV CAMERAS.
# EN-SUITE ROOM.
# DINING AREA.
# WARDROBES.
# AIR CONDITIONER.
# GOOD ROAD ACCESS.
# SECURED NEIGHBOURHOOD.
# Amenities
# Security Fence
# Parking
# Balcony
#
# 4BEDROOM WITH 1BEDROOM STAFF QUARTERS NEWLY BUILT HOUSE FOR SALE AT EAST LEGON.
#
# PRICE:$280,000USD NEGOTIABLE
#
# Appliances
# Air Condition
# Amenities
# Security Fence
# CCTV
# Swimming Pool
# Gym
# Super market
# Balcony
# Office space
#
# GYM.
# OFFICE SPACE.
# SUPER MARKET AREA.
# SWIMMING POOL AREA.
# CONFERENCE HALL AREA.
#
# FULLY FITTED KITCHEN WITH CABINET AND APPLIANCES.
# BALCONY SPACE WITH GREAT VIEW.
# CCTV CAMERAS.
# EN-SUITE ROOM.
# DINING AREA.
# WARDROBES.
# AIR CONDITIONER.
# GOOD ROAD ACCESS.
# SECURED NEIGHBOURHOOD.
#
# STUDIO STARTING PRICE FROM ($66,750USD-26sqm-sq/ft280).
# ($70,000USD-28sqm-sq/ft301).
# ($75,400USD-29sqm-sq/312).
# ($78,000USD-30sqm-sq/ft323).
# ($79,050USD -31sqm-sq/ft334).
# ($81,600USD-32sqm-sq/ft344).
# ($88,400USD-34sqm-sq/ft366)
# ($98,050USD-37sqm-sq/ft398).
#
# Appliances
# Dishwasher
# Water Heater
# Microwave
# Air Condition
# Recess Light
# Gas Range
# Electric Cooker
# Washing Machine
# Kitchen extractor
# Amenities
# Security Fence
# 24-hour Security
# CCTV
# Water storage and pumping system
# Swimming Pool
# Parking
# Gym
#
# Le Luxe as its name suggests, is a prestigious development of stylish, luxurious three-bedroom town homes & two-bedroom apartments. It is nestled within a beautiful and safe community where everything needed for a comfortable lifestyle is within reach. Le Luxe is close to local transport links, renowned healthcare and hospitality centres as well as well – regarded schools for children.
# The development is designed with simple, minimalist yet striking architecture. This modern community is finished to a high specification, with a secure gated entrance, elegant and spacious interiors, and outstanding external textures.
# Each house offers open, light – filled, contemporary interiors, a private backyard and dedicated parking space. It is the perfect accommodation option for singles, couples or small families with a taste for the luxe of life.
#
# All rooms ensuite
# Fitted kitchen cabinets
# Fitted wardrobes
# P.O.P Ceilings
# Tiled compound
# Price is GHS720,000
# Appliances
# Air Condition
# Amenities
# Security Fence
# CCTV
# Car Port
#
# Newly Built 4 Bedrooms House for Sale Along the New East Legon Hills Road Before Melcom
# Has 3 bedrooms en suite
# 1 bq ensuite
# Visitor's washroom
# Big hall with dining area
# Family area at the top
# Modern kitchen fittted with cabinets
# Big compound
# Garage
# 24/7 Security
# Gated community
# Only 4 units left
# Price is GHS2,184,000
#
# Newly Built 4 Bedrooms House for sale at Adenta New Legon Area
# #Specifications
# All bedroo.s are spacious and en suite
# Big hall with dining area
# Serene and cozy neighbourhood
# Great proximity to principal streets
# Parking lodge
# Beautiful floral decor
# Guest washroom
# Beautiful lightening
# Spacious kitchen
# Spacious ensuite room
# Perimeter fence
# Automated gate
# Open plan kitchen
# Fitted kitchen
# fridge
# extractor
# Wardrobes
# Land Title Certificate Documents
# Price is GHS1,330,000
#
# NEWLY EXECUTIVE 3  MASTER BEDROOMS HOUSE WITH ONE BOYS QUARTERS FOR SALE @ ASHONGMAN
# All bedrooms en suite
# Guest washroom
# Big hall with dining area
# Fittted kitchen
# In built wardrobes
# ACs and water heaters installed
# Boys quarters,  also ensuite
# Big compound for open parking
# Good and serene environment
# PRICE IS GHS1,480,000
#
# This is a new fully furnished 4 Bedrooms House for Sale at Gbawe Hills
#
# All bedrooms en-suite
# Visitor's washroom
# Big Hall with dining area
# Wine area
# In built wardrobes
# ACs and heaters in all rooms
# Kitchen fitted with cabinets
# Fully furnished
# Big compound for open parking
# CCTV Security System
# You will love it
# Price is US$300,000
#
# EXECUTIVE 4 BEDROOMS LUXURY HOUSE WITH BOYS QUARTERS FOR SALE.
# LOCATION: â¤µï¸â¤µï¸
# Community 17, Spintex
# LANDMARKS: â¤µï¸â¤µï¸
# Excel Community School, Shell Service Station, DStV office, Tema West Municipal Assembly, Amadia Shopping Mall,Gustav Restaurant etc.
# FEATURES: â¤µï¸â¤µï¸
# â–¶ï¸1 Executive Master Bedroom with Living Room.
# â–¶ï¸ Spacious 3 Bedrooms with Closet
# â–¶ï¸ Jacuzzi
# â–¶ï¸ Standing Shower ðŸš¿
# â–¶ï¸ Spacious Car Parking
# â–¶ï¸ Fully Fitted Kitchens  finished with
# Refrigerator, Microwave, Oven, Heat Extractor, Cooker.
# â–¶ï¸ All Rooms are En-Suits
# â–¶ï¸Total of Five (6) Washrooms
# â–¶ï¸ Air-conditions
# â–¶ï¸ Pop and Decorated Plaster Board ceiling.
# â–¶ï¸ Security Post.
# â–¶ï¸ Boys Quarters
# OTHER FEATURES INCLUDE: â¤µï¸â¤µï¸
# â–¶ï¸ Quality and Beautiful Finishing.
# â–¶ï¸ Spanish Quality Tiles
# â–¶ï¸ Spacious Balcony for Relaxing
# â–¶ï¸ Electric Fence
# â–¶ï¸ Led Lighting
# â–¶ï¸ Remote Control Gate
# â–¶ï¸ Serene and Secure Environment.
# Price is GHS2.3 million
#
#
# Unipac Properties are proud to present this rare opportunity to buy a 5 bedroom house at East Cantonments on two plots of land.
# Call Unipac Properties for full details.
# (The photo attached is not the real image of the property)
#
# LUXURIOUS AND HUGE 5 BEDROOMS MANSION WITH SWIMMING POOL FOR SALE @ East Legon Hills( on 2 plots)
# *5 very luxurious and spacious  bedrooms all ensuite
# *Huge Walk in closets and spacious fitted wardrobes
# *Ultra modern fitted kitchen
# *Automated garages for 4 cars
# *Automated entrance gate
# *Borehole to supply water 24/7
# *Swimming pool
# *Electric fence installed
# *Alarm system installed
# *Provision is made for generator, solar system and panels
# *Spacious security post
# Property is sitting on 2 plots.
# House is on 1 Plot
# Compound covers the other 1 plot.
# Price is US$500,000
# Contact Darwin Agency on 0240098876
#
# Amenities
# Swimming Pool
# Parking
#
# Ex four bedrooms house for sale at east legon 400.000$ negotiable
# Contact me on 0246744103 for viewing
# Agency Terms Applies
#
# 4 bedrooms house for sale at Tantra hill
#   250,000 usd negotiable
# Contact me on 0246744103 for viewing
# Agency Terms Applies
# Amenities
# Swimming Pool
# Solar Energy
# Parking
# Gym
#
# 3bedroom house for sale at east legon hills fully furnished
# All rooms en-suite with fully fitted kitchen
# The house comes with solar
# With a big compound
# The estate has a pool a gym a garden nd a club house
# Price is 220,000$ negotiable
# Contact me on 02467444103 for viewing
# Agency Terms Applies
#
# 3 bedroom house for sale around oyarifa and is going for 400,000ghc but negotiable
# Contact me on 0246744103 for viewing
# Agency Terms Applies
#
# This is a newly built 3 bedroom house located at East Legon Hills in a gated community
# Going for sale
# Price $150,000 negotiable
# Contact me on 0246744103 for viewing
# Agency Terms Applies
#
# Amenities
# Parking
#
# 3 bedroom semi detached
# 4 washroom
# 2 cars parking lot
# 450.000gh negotiable and a fitted kitchen
# Contact me on 0246744103 for viewing
# Agency Terms Applies
#
# Amenities
# Swimming Pool
#
# 3 Bedroom house for sale in a
# Gated community at Abokobi
# Community swimming pool
# Play ground for children
# Tarred road in between the houses
# Security check point
# $90,000
# Contact me on 0246744103 for viewing
# Agency Terms Applies
#
# This is a newly built 4  Bedrooms house for sale around Manet,  along the MANET-LEKMA road , less than 10 mins drive from the new China Mall
#                 FEATURES
# Four (4) ensuite bedrooms
# Visitors wahroom
# Neat finishing
# Spacious Rooms
# Modern Security Doors
# Huge parking space
# Gated communit ly
# Secured Neighborhood
# LAND TITLED
# Price is GHS1.4 million
# Buyers can pay half, move in and pay the rest in 2 years
#
# Newly Built 4 bedrooms house for sale @ Lakeside Estate
#   All bedrooms en suite
# Visitor's washroom
# 2 Living areas
# Dining area
# Fittted kitchen
# In built wardrobes
# Master with walk in closet
# ACs installed
# Big compound for open parking
# Secured environment
# Price is GHS1.8 million
#
# All bedrooms ensuite
# Visitor's washroom
# Big hall with dining area
# Kitchen fitted with cabinet
# Fridge, oven, burner, heat extractor,
# Microwave and washing machine provided
# Big compound space
# Car port
# Quality furniture and finishing
# You'll love it
# Price is a cool GHS2,060,000
# For viewing of property, contact Darwin Agency on 0240098876
#
# All bedrooms are en suite and very big
# Visitor's washroom
# Big hall with dining area
# Fully equipped and fitted kitchen
# Boys quarters
# ACs and Fans installed
# Big compound space
# Full plot
# Good location
# Price is GHS2,000,000
# For viewing of property, contact the agent at 0240098876
#
# NEWLY BUILT  THREE BEDROOM HOUSE FOR SALE
# 92% DONE
# BUDGET/PRICE: GHC650,000
# NO. OF BEDROOMS: 3
# N0. OF WASHROOMS:3.5
# EARLY BIRD GETS A COOL DEAL
# Appliances
# Water Heater
# Amenities
# Parking
#
# Appliances
# Water Heater
# Microwave
# Air Condition
# Recess Light
# Washing Machine
# Amenities
# Security Fence
# CCTV
# Swimming Pool
# Parking
#
# Newly Built 4 bedrooms house for sale at East Legon ARS, less than 2 minutes drive from the ARS roundabout
# All bedrooms en suite
# Visitor's washroom
# Laundry room
# Kitchen fittted with cabinets
# Kitchen store room
# Microwave,  stove fridge,  water heater and heat extractor provided
# ACs installed
# 2 bedrooms have inner closet
# Other 2 bedrooms have in built wardrobes
# CCTV security system
# Swimming pool
# Big compound for open parking
# POP ceiling
#   Price is GHS2,440,000
# Appliances
# Water Heater
# Air Condition
# Amenities
# Water storage and pumping system
# Parking
#
# NEWLY BUILT 4 BEDROOM HOUSE FOR SALE
# NO. OF BEDROOMS:4
# NO. OF WASHROOMS: 5
# PRICE:$350,000
# EXTRA FEATURES/AMENITIES: TWO LIVING AREAS, AIR CONDITIONING, DOUBLE WIRING, DINING AREA, WARDROBES, GARDEN, PIPE BORNE WATER, RESERVOIRS, BOYS QUARTERS, AMPLE PARKING SPACE.
# Appliances
# Water Heater
# Air Condition
# Amenities
# Water storage and pumping system
# Parking
#
# NEWLY BUILT 4 BEDROOM HOUSE FOR SALE
# NO. OF BEDROOMS:4
# NO. OF WASHROOMS: 5
# EXTRA FEATURES/AMENITIES: TWO LIVING AREAS, AIR CONDITIONING, DOUBLE WIRING, DINING AREA, WARDROBES, GARDEN, PIPE BORNE WATER, RESERVOIRS, BOYS QUARTERS, AMPLE PARKING SPACE.
#
# Newly built 4 bedrooms self compound house for sale in a gated community @ East Legon around AnC
# All bedrooms en suite
# Visitor's washroom
# Big hall with dining area
# Fittted kitchen
# ACs and water heaters installed
# Big compound
# Secured environment
# Price is GHS3.6 million
#
# Newly Built 4 bedrooms House with 1 bedroom boys quarters for SALE AT Tema Comm 19
#   All bedrooms en suite
# Visitor's washroom
# 2 living areas with dining area
# Kitchen fittted with cabinets
# Kitchen store room
# Gym centre
# Central alarm system
# Swimming pool
# Electric security fence
# Big compound space
# Car Port
# 1 bedroom boys quarters
# Price is GHS5.2 million
#
#   Newly Built 3 bedrooms smart house for sale at Lakeside Estate Community 8.
# All bedrooms en-suite
# Visitor's washroom
# Big hall with dining area
# Modern kitchen fittted with cabinets
# ACs installed in all rooms
# Ceiling fans I
# n-built wardrobes
# Solar Powered Home
# POP ceiling Spotlights
# Serene and secured Neighborhood
# Water reservoirs
# Water Heaters Smart or Automated home
# Building along the main road
# Land size is 35*100 square feet
# Note: All units are expected to be completed by end of July this year. 4 units available
#   Price is GHS1 million
#
# 10 ACRES OF TITLED LAND AVAILABLE FOR SALE AT ABOKOBI HILLS, ACCRA.
# 25 MINUTES DRIVE FROM THE AIRPORT.
# PRICE:GHC75,000 (NEGOTIABLE)
#
# Executive 5-bedroom fully finished smart luxury self house for sale location
# east Legon not far from American house
# . This property has an extra room for an office/study as well as a 1 bed boys Quarters. It has smart lights + Ambient lighting + Motion Sensor lights, Smart wireless appliances, voice controlled smart entertainment systems, panoramic double glazed windows, smart window blinds, keyless entry and exit, pool and bar.
# Selling Price : $620,000(negotiable). Contact me on 0246744103 for viewing. Agency Terms Applies
#
# Furnished 3 Bedrooms house For sale at lakeside community 8 price 170000$ negotiable.Contact me on 0246744103 for viewing. Agency Terms Applies
#
# Executive furnished 4  bedroom is up for sale at tantra hills and is going for 380,000$ negotiable.Contact me on 0246744103 for viewing. Agency Terms Applies
#
# 4bedroom fully furnished for sale at East legon hills going for 200,000$.Contact me on 0246744103 for viewing. Agency Terms Applies
#
# This is a newly built 3bedroom self house located at Ashaly Botwe Japan-motors
# All rooms en-suite
# Very good and accessible road
# It has a land title documents
# Very spacious compound
# Inbuilt wardrobes
# Sleek washrooms
# It has a car port
# Very close to the main road
# Price 550.000 negotiable.Contact me on 0246744103 for viewing. Agency Terms Applies
#
# 4 bedrooms house for sale at east legon hills going for cuul 270,000 usd slightly negotiable.contact me on 0246744103 for viewing.Agency Terms Applies
#
# The property is located at Daaban residential area in Kumasi. Is a 5 bedroom house all en-suite with 2 bedrooms boys quarters. Well fenced with electric wire. 24/7 water and electricity. The price is GH1.6 million cedis but negotiable. It's a judicial/auction sale.

# %%
df.columns
# Out:
# Index(['_id', 'source', 'category', 'price', 'house_details', 'other_details',
#        'location', 'phone', 'images', 'currency', 'duration', 'region', 'city',
#        'sub', 'no_of_bedrooms', 'no_of_bathrooms'],
#       dtype='object')

# %%
filtered = []
for row in df.itertuples(name = 'RealEstate'):
    if len(row.images) > 1:
        filtered.append(row.Index)

# %%
df = df.iloc[filtered] #removed rows with less than 2 images

# %%
df= df[df['duration'].isin(['N/A']) & df['region'].isin(['Greater Accra Region'])]

# %%
df.head(3)
# Out:
#                         _id        source  category       price  \
# 0  64c8106ad2b80fc9a5e08ff1  efiewura.com  for sale  125,000.00
# 2  64c8106dd2b80fc9a5e08ff3  efiewura.com  for sale  165,000.00
# 3  64c8106fd2b80fc9a5e08ff4  efiewura.com  for sale  100,000.00
#
#                  house_details  \
# 0  {'Beds': '4', 'Baths': '4'}
# 2  {'Beds': '3', 'Baths': '3'}
# 3  {'Beds': '3', 'Baths': '3'}
#
#                                        other_details  \
# 0  Appliances\nWater Heater\nWardrobes\nAmenities...
# 2
# 3
#
#                                             location phone  \
# 0  [Greater Accra Region,  Accra,  Lakeside Estat...
# 2  [Greater Accra Region,  Tema,  Tema Community 22]
# 3  [Greater Accra Region,  Tema,  Tema Community 22]
#
#                                               images currency duration  \
# 0  [https://efiewura.com/img/properties/executive...      GHS      N/A
# 2  [https://efiewura.com/img/properties/3_bedroom...      GHS      N/A
# 3  [https://efiewura.com/img/properties/3_bedroom...      GHS      N/A
#
#                  region    city                 sub no_of_bedrooms  \
# 0  Greater Accra Region   Accra     Lakeside Estate              4
# 2  Greater Accra Region    Tema   Tema Community 22              3
# 3  Greater Accra Region    Tema   Tema Community 22              3
#
#   no_of_bathrooms
# 0               4
# 2               3
# 3               3

# %%
df = df.drop(['source','house_details','phone','location'],axis =1)

# %%
df.head()
# Out:
#                         _id  category       price  \
# 0  64c8106ad2b80fc9a5e08ff1  for sale  125,000.00
# 2  64c8106dd2b80fc9a5e08ff3  for sale  165,000.00
# 3  64c8106fd2b80fc9a5e08ff4  for sale  100,000.00
# 4  64c81070d2b80fc9a5e08ff5  for sale  280,000.00
# 5  64c81072d2b80fc9a5e08ff6  for sale  250,000.00
#
#                                        other_details  \
# 0  Appliances\nWater Heater\nWardrobes\nAmenities...
# 2
# 3
# 4
# 5  Appliances\nDishwasher\nMicrowave\nAir Conditi...
#
#                                               images currency duration  \
# 0  [https://efiewura.com/img/properties/executive...      GHS      N/A
# 2  [https://efiewura.com/img/properties/3_bedroom...      GHS      N/A
# 3  [https://efiewura.com/img/properties/3_bedroom...      GHS      N/A
# 4  [https://efiewura.com/img/properties/3_bedroom...      USD      N/A
# 5  [https://efiewura.com/img/properties/4_bedroom...      USD      N/A
#
#                  region    city                 sub no_of_bedrooms  \
# 0  Greater Accra Region   Accra     Lakeside Estate              4
# 2  Greater Accra Region    Tema   Tema Community 22              3
# 3  Greater Accra Region    Tema   Tema Community 22              3
# 4  Greater Accra Region    Tema   Tema Community 22              3
# 5  Greater Accra Region   Accra     New Legon Hills              4
#
#   no_of_bathrooms
# 0               4
# 2               3
# 3               3
# 4               2
# 5               5

# %%
df['city'].value_counts()
# Out:
#  Accra       373
#  Tema         27
#  Other         6
#  Afienya       3
#  Oyibi         2
#  Ada-Foah      1
#  Ashaiman      1
# Name: city, dtype: int64

# %%
def citywrangler(x):
    if x.__contains__('Accra'):
        return 'Accra'
    else:
        return "Other"

# %%
df['city'] = df['city'].apply(citywrangler)

# %%
df
# Out:
#                           _id  category         price  \
# 0    64c8106ad2b80fc9a5e08ff1  for sale    125,000.00
# 2    64c8106dd2b80fc9a5e08ff3  for sale    165,000.00
# 3    64c8106fd2b80fc9a5e08ff4  for sale    100,000.00
# 4    64c81070d2b80fc9a5e08ff5  for sale    280,000.00
# 5    64c81072d2b80fc9a5e08ff6  for sale    250,000.00
# ..                        ...       ...           ...
# 434  64c813e2d2b80fc9a5e091a3  for sale  1,278,400.00
# 435  64c813e4d2b80fc9a5e091a4  for sale  2,857,600.00
# 436  64c813e6d2b80fc9a5e091a5  for sale  1,504,000.00
# 437  64c813e8d2b80fc9a5e091a6  for sale    550,000.00
# 438  64c813ead2b80fc9a5e091a7  for sale  2,030,400.00
#
#                                          other_details  \
# 0    Appliances\nWater Heater\nWardrobes\nAmenities...
# 2
# 3
# 4
# 5    Appliances\nDishwasher\nMicrowave\nAir Conditi...
# ..                                                 ...
# 434  \nFurnished 3 Bedrooms house For sale at lakes...
# 435  \nExecutive furnished 4  bedroom is up for sal...
# 436  \n4bedroom fully furnished for sale at East le...
# 437  \nThis is a newly built 3bedroom self house lo...
# 438  \n4 bedrooms house for sale at east legon hill...
#
#                                                 images currency duration  \
# 0    [https://efiewura.com/img/properties/executive...      GHS      N/A
# 2    [https://efiewura.com/img/properties/3_bedroom...      GHS      N/A
# 3    [https://efiewura.com/img/properties/3_bedroom...      GHS      N/A
# 4    [https://efiewura.com/img/properties/3_bedroom...      USD      N/A
# 5    [https://efiewura.com/img/properties/4_bedroom...      USD      N/A
# ..                                                 ...      ...      ...
# 434  [https://efiewura.com/img/properties/furnished...      GHC      N/A
# 435  [https://efiewura.com/img/properties/executive...      GHC      N/A
# 436  [https://efiewura.com/img/properties/4bedroom_...      GHC      N/A
# 437  [https://efiewura.com/img/properties/this_is_a...      GHC      N/A
# 438  [https://efiewura.com/img/properties/_4_bedroo...      GHC      N/A
#
#                    region   city                           sub no_of_bedrooms  \
# 0    Greater Accra Region  Accra               Lakeside Estate              4
# 2    Greater Accra Region  Other             Tema Community 22              3
# 3    Greater Accra Region  Other             Tema Community 22              3
# 4    Greater Accra Region  Other             Tema Community 22              3
# 5    Greater Accra Region  Accra               New Legon Hills              4
# ..                    ...    ...                           ...            ...
# 434  Greater Accra Region  Accra          Lakeside community 8              3
# 435  Greater Accra Region  Accra                  Tantra Hills              4
# 436  Greater Accra Region  Accra              East Legon Hills              4
# 437  Greater Accra Region  Accra   Ashaley Botwe Japan -Motors              3
# 438  Greater Accra Region  Accra              East Legon Hills              4
#
#     no_of_bathrooms
# 0                 4
# 2                 3
# 3                 3
# 4                 2
# 5                 5
# ..              ...
# 434               3
# 435               4
# 436               4
# 437               3
# 438               4
#
# [413 rows x 12 columns]

# %%
df['sub'].value_counts()
# Out:
#  Oyarifa                        19
#  East Legon                     16
#  East Legon Hills               15
#  Spintex                        13
#  East legon                     10
#                                 ..
#  West Legon                      1
#  Amasaman Sonitra Junction       1
#  Sapeiman( Amasaman)             1
#  North Kaneshie                  1
#  Ashaley Botwe Japan -Motors     1
# Name: sub, Length: 210, dtype: int64

# %%
for i in df['sub'].unique():
    if i.lower().__contains__('legon'):
        print(i)
# Out:
#  New Legon Hills
#  East Legon (Trassaco/Adjiringanor)
#  Eastlegon hills
#  EAST LEGON HILL
#  East legon hill
#  Eastlegon
#  NORTH LEGON
#  EASTLEGON
#  East legon
#  EAST LEGON
#  West legon
#  New Legon
#  East Legon
#  East Legon UPSA
#  North Legon
#  Agbogba North Legon
#  East Legon around AH hotel
#  East Legon Hills
#  East Legon Agringanor
#  East Legon behind Pinkberry ice cream
#  West Legon
#  Adenta New Legon
#  Adenta new legon
#  EAST LEGON HILLS
#  East Legon Trasacco
#  East Legon - Adjiringanor
#  East Legon hills

# %%
def subwrangler(x):
    if x.lower().__contains__('legon'):
        if x.lower().__contains__('Agbogba') or x.lower().__contains__('Adenta'):
            pass
        else:
            print(x)
            return 'Legon'
    else:
        return x

# %%
df['sub'] = df['sub'].apply(subwrangler)
# Out:
#  New Legon Hills
#  East Legon (Trassaco/Adjiringanor)
#  East Legon (Trassaco/Adjiringanor)
#  Eastlegon hills
#  EAST LEGON HILL
#  East legon hill
#  Eastlegon hills
#  Eastlegon
#  Eastlegon
#  Eastlegon
#  Eastlegon hills
#  NORTH LEGON
#  Eastlegon hills
#  EASTLEGON
#  East legon hill
#  East legon
#  East legon hill
#  East legon
#  New Legon Hills
#  NORTH LEGON
#  EAST LEGON HILL
#  East legon
#  EAST LEGON
#  West legon
#  East legon
#  New Legon
#  East Legon
#  East Legon UPSA
#  North Legon
#  EAST LEGON HILL
#  EAST LEGON HILL
#  East legon hill
#  East Legon
#  Agbogba North Legon
#  EAST LEGON
#  East Legon
#  North Legon
#  East Legon
#  East Legon around AH hotel
#  East Legon Hills
#  East Legon Hills
#  East Legon Agringanor
#  East Legon behind Pinkberry ice cream
#  East Legon Hills
#  East Legon
#  West Legon
#  NORTH LEGON
#  East Legon
#  East Legon
#  Adenta New Legon
#  East Legon Agringanor
#  East legon
#  East legon
#  EAST LEGON
#  East legon hill
#  East legon hill
#  East legon
#  East legon hill
#  East legon hill
#  East legon hill
#  Adenta new legon
#  East legon
#  East legon
#  East Legon
#  West legon
#  West legon
#  East legon
#  East Legon Hills
#  East Legon Hills
#  East Legon
#  East Legon Hills
#  East Legon Hills
#  East Legon Hills
#  North Legon
#  East Legon
#  East Legon Hills
#  EAST LEGON
#  EAST LEGON HILLS
#  EAST LEGON
#  East Legon Trasacco
#  East Legon
#  East Legon
#  East Legon Hills
#  East Legon
#  East Legon - Adjiringanor
#  EAST LEGON
#  EAST LEGON
#  East Legon Hills
#  Adenta New Legon
#  East Legon Hills
#  East Legon
#  East Legon Hills
#  East Legon hills
#  EAST LEGON HILLS
#  East Legon
#  East Legon
#  East Legon Hills
#  East Legon Hills

# %%
df['sub'].unique()
# Out:
# array([' Lakeside Estate', ' Tema Community 22', 'Legon',
#        ' Cantonment/ Labone', ' Airport West',
#        ' Tse-Addo (Near Cantonments & Labone)', ' Accra',
#        ' Sapeiman( Amasaman)', ' Fise(Amasaman)', ' Tantra Hills',
#        ' Mataheko', ' Roman Ridge', ' Cantonments', ' Cantoments',
#        ' Oyarifa', ' Abokobi', ' Old Ashongman', ' Tema', ' Botwe',
#        ' Tema community 25', ' Amasaman', ' East Airport', ' Lakeside',
#        ' TSEADDO', ' Airport residential Area', ' Amrahia',
#        ' AIRPORT RESIDENTIAL AREA', ' Shiashie', ' Sakumono',
#        ' Cambodia spintex', ' Tseaddo', ' Pantang', ' Keabenya ACP',
#        ' Roman Rudge', ' Labone', ' Airport Hill', ' Hatso',
#        ' Tantra hill', ' Oyarifa special', ' Kashibj', ' Katamanso',
#        ' Adenta - Katamanso', ' Trasacco', ' Westland', ' Madina Ogbojo',
#        ' Adenta ssnit flat', ' Lashibi spintex', ' Spintex',
#        ' Adjiringanor', ' Airport residential area', ' Cantonment',
#        ' Botwe school junction', ' McCarthy Hill', ' Botwe Pentecost',
#        ' Oyarifa Focos', ' Airport Residential Area', ' Pantang junction',
#        ' BOTWE SCHOOL JUNCTION', ' Airport', ' SPINTEX COMMUNITY 18',
#        ' Adenta Amanfrom', ' Abokobi Boi', ' Oyarifa - Special Ice',
#        ' Trassaco', ' Spintex signboard', ' Musuku', ' North Ridge',
#        ' Achimota Tantra-Hills', ' Airport Hills', ' Lapaz',
#        ' SPINTEX COM 18', ' Lakeside Estate Community 5',
#        ' Dome Pillar 2', ' Ashaley Botwe Sch Junct. Near NanaKrom Melcom',
#        ' Adenta', ' Burma Hills', ' Okpoi-Gonno', ' Ashley Botwe',
#        ' Spintex Coastal', ' Trassaco Valley', ' Tabora Alhaji',
#        ' East Adjiriganor', ' Achimota (Tantra Hill Residential Area)',
#        ' American house', ' Amasaman Sonitra Junction',
#        ' Ashongman Estates', ' North Kaneshie', ' Spintex Community 20',
#        ' Haatso Ecomog', ' Haatso Atomic', ' Dawhenya',
#        ' Lakeside Estate Community 8', ' Amasaman Sonitra',
#        ' Haatso Boshye', ' Sarpeiman', ' Mallam', ' Spintex kasspreko',
#        ' Spintex ecobank', ' Batsonaa', ' KUTUNSE satellite', ' Lashibi',
#        ' Ogbojo', ' Adjringanor', ' Ashaley Botwe - Nana Krom',
#        ' Tse addo', ' Malejor', ' Oyibi - Bush Canteen',
#        ' OYARIFA ayi mensah', ' Community 25', ' Tantra Hill',
#        ' Trassacco estate', ' Tulaku', ' Spintex Manet',
#        ' Spintex Greda estate', ' Amasaman China mall', ' Dzorwulu',
#        ' Adenta Housing Down', ' Agbogba', ' Coastal estate',
#        ' Adenta pantang', ' TRASSACCO Estate', ' Greda Estate',
#        ' Sakumono SSNIT Flat', ' Achimota', ' Spintex sakumono estate',
#        ' Lakeside estate', ' Afienya-Mataheko',
#        ' Off the Tema-Aflao road', ' Ada', ' Community 25 Tema',
#        ' Free Zone', ' Tema Community 25', ' Kaneshie', ' Ashiaman',
#        ' Tema community10', ' Gbetsile Michel Camp.Tema',
#        ' Afienya mataheko.Tema', ' Golf City.Tema community25', ' Nungua',
#        ' Afienya Jerusalem.Tema', ' Community24', ' Malejor-Oyibi',
#        ' Afienya', ' Ablekuma', ' Spintex Road', ' spintex', ' Zion city',
#        ' Ashongman', ' Taifa', ' Madina', ' Oyibi', ' Tema Aflao Road',
#        ' Abelemkpe', ' Ashongman Estate', ' Kwabenya', ' Tesano',
#        ' Lakeside Estates', ' ACP JUNCTION', ' Addogono', ' Adjiriganor',
#        ' Adenta Sakora', ' AMERICAN HOUSE', ' ADJIRIGANOR',
#        ' Westhills Mall', ' MEMPEASEM', ' ASHALEY BOTWE', ' Pokuase',
#        ' COMMUNITY 6', ' DOME', ' TEIMAN', ' KWASHIEMAN', ' EAST AIRPORT',
#        ' Community 25 Devtraco', ' Lashibi Collins Dauda', ' Bortianor',
#        ' AMASAMAN', ' Kpone Barrier', ' Gbawe', ' Teshie Lekma',
#        ' LAKESIDE', ' Tema Community 19', ' ABOKOBI HILLS',
#        ' Lakeside community 8', ' Ashaley Botwe Japan -Motors'],
#       dtype=object)

# %%
df['sub'] = df['sub'].replace({' Adjiriganor':"Legon",' Shiashie':"Legon",' Adjiringanor':"Legon",' American house':"Legon",' Adjringanor':"Legon",' ADJIRIGANOR':"Legon",' AMERICAN HOUSE':"Legon",' Westland':"Legon",
                   ' Adenta Sakora':"Adenta",' Adenta - Katamanso':"Adenta",' Adenta ssnit flat':"Adenta",' Adenta Amanfrom':'Adenta',' Adenta':"Adenta",' Adenta Housing Down':"Adenta",' Adenta pantang':"Adenta",
                   ' Cantonment/ Labone':"Cantonments",' Cantoments':"Cantonments",' Cantonment':"Cantonments"," Cantonments":"Cantonments",
                   ' Cambodia spintex':"Spintex",' Lashibi spintex':"Spintex",' Spintex':"Spintex",' SPINTEX COMMUNITY 18':"Spintex",' Spintex signboard':"Spintex",' SPINTEX COM 18':"Spintex", ' Spintex Coastal':"Spintex",' spintex':"Spintex",' Spintex Road':"Spintex",
                               ' Spintex sakumono estate':"Spintex",' Spintex Manet':"Spintex",' Spintex Greda estate':"Spintex",' Spintex Community 20':"Spintex",' Spintex ecobank':"Spintex",' Spintex kasspreko':"Spintex",
                   ' Tema Community 22':"Tema", ' Tema':"Tema",' Tema community 25':"Tema",' Teshie Lekma':"Tema",' Tema Community 19':"Tema",' Community 25':"Tema",' Golf City.Tema community25':"Tema",' Community24':"Tema",' Community 25 Tema':"Tema",' Off the Tema-Aflao road':"Tema",
                               ' Afienya Jerusalem.Tema':"Tema",' COMMUNITY 6':"Tema",' Afienya-Mataheko':"Tema",' Afienya':"Tema",' Tema Community 25':"Tema",' Tema community10':"Tema",' Afienya mataheko.Tema':"Tema",' Tema Aflao Road':"Tema",' Nungua':"Tema",' Ashiaman':"Tema",' Gbetsile Michel Camp.Tema':"Tema",' Community 25 Devtraco':"Tema",
                               ' Oyarifa special':"Oyarifa",' Oyarifa':"Oyarifa",' Oyarifa Focos':"Oyarifa",' Oyarifa - Special Ice':"Oyarifa",' OYARIFA ayi mensah':"Oyarifa",
                  ' Airport West':"Airport",' East Airport':"Airport",' Airport':"Airport",' Airport Residential Area':"Airport",' AIRPORT RESIDENTIAL AREA':"Airport",' Airport Hill':"Airport",' Airport residential area':"Airport",' Airport Residential Area':"Airport",' Airport Hills':"Airport"
                  })

# %%
df['sub'].unique()
# Out:
# array([' Lakeside Estate', 'Tema', 'Legon', 'Cantonments', 'Airport',
#        ' Tse-Addo (Near Cantonments & Labone)', ' Accra',
#        ' Sapeiman( Amasaman)', ' Fise(Amasaman)', ' Tantra Hills',
#        ' Mataheko', ' Roman Ridge', 'Oyarifa', ' Abokobi',
#        ' Old Ashongman', ' Botwe', ' Amasaman', ' Lakeside', ' TSEADDO',
#        ' Airport residential Area', ' Amrahia', ' Sakumono', 'Spintex',
#        ' Tseaddo', ' Pantang', ' Keabenya ACP', ' Roman Rudge', ' Labone',
#        ' Hatso', ' Tantra hill', ' Kashibj', ' Katamanso', 'Adenta',
#        ' Trasacco', ' Madina Ogbojo', ' Botwe school junction',
#        ' McCarthy Hill', ' Botwe Pentecost', ' Pantang junction',
#        ' BOTWE SCHOOL JUNCTION', ' Abokobi Boi', ' Trassaco', ' Musuku',
#        ' North Ridge', ' Achimota Tantra-Hills', ' Lapaz',
#        ' Lakeside Estate Community 5', ' Dome Pillar 2',
#        ' Ashaley Botwe Sch Junct. Near NanaKrom Melcom', ' Burma Hills',
#        ' Okpoi-Gonno', ' Ashley Botwe', ' Trassaco Valley',
#        ' Tabora Alhaji', ' East Adjiriganor',
#        ' Achimota (Tantra Hill Residential Area)',
#        ' Amasaman Sonitra Junction', ' Ashongman Estates',
#        ' North Kaneshie', ' Haatso Ecomog', ' Haatso Atomic', ' Dawhenya',
#        ' Lakeside Estate Community 8', ' Amasaman Sonitra',
#        ' Haatso Boshye', ' Sarpeiman', ' Mallam', ' Batsonaa',
#        ' KUTUNSE satellite', ' Lashibi', ' Ogbojo',
#        ' Ashaley Botwe - Nana Krom', ' Tse addo', ' Malejor',
#        ' Oyibi - Bush Canteen', ' Tantra Hill', ' Trassacco estate',
#        ' Tulaku', ' Amasaman China mall', ' Dzorwulu', ' Agbogba',
#        ' Coastal estate', ' TRASSACCO Estate', ' Greda Estate',
#        ' Sakumono SSNIT Flat', ' Achimota', ' Lakeside estate', ' Ada',
#        ' Free Zone', ' Kaneshie', ' Malejor-Oyibi', ' Ablekuma',
#        ' Zion city', ' Ashongman', ' Taifa', ' Madina', ' Oyibi',
#        ' Abelemkpe', ' Ashongman Estate', ' Kwabenya', ' Tesano',
#        ' Lakeside Estates', ' ACP JUNCTION', ' Addogono',
#        ' Westhills Mall', ' MEMPEASEM', ' ASHALEY BOTWE', ' Pokuase',
#        ' DOME', ' TEIMAN', ' KWASHIEMAN', ' EAST AIRPORT',
#        ' Lashibi Collins Dauda', ' Bortianor', ' AMASAMAN',
#        ' Kpone Barrier', ' Gbawe', ' LAKESIDE', ' ABOKOBI HILLS',
#        ' Lakeside community 8', ' Ashaley Botwe Japan -Motors'],
#       dtype=object)

# %%
pd.DataFrame(df['sub'].value_counts()).head(20)
# Out:
#                     sub
# Legon               112
# Tema                 28
# Spintex              27
# Airport              25
# Oyarifa              24
# Cantonments          12
# Adenta               12
#  Abokobi              6
#  Tseaddo              5
#  Lakeside Estate      5
#  Accra                5
#  Tantra Hills         5
#  Roman Ridge          4
#  Tantra hill          4
#  Oyibi                4
#  Sakumono             3
#  Ashongman Estates    3
#  Trassaco             3
#  Ashongman            3
#  Botwe                3

# %%
def subwrangler2(x):
    if x not in ['Legon',"Spintex","Tema","Oyarifa","Adenta","Airport","Cantonments"]:
        return "Other"
    else:
        return x

# %%
df['sub'] = df['sub'].apply(subwrangler2)

# %%
df.head()
# Out:
#                         _id  category       price  \
# 0  64c8106ad2b80fc9a5e08ff1  for sale  125,000.00
# 2  64c8106dd2b80fc9a5e08ff3  for sale  165,000.00
# 3  64c8106fd2b80fc9a5e08ff4  for sale  100,000.00
# 4  64c81070d2b80fc9a5e08ff5  for sale  280,000.00
# 5  64c81072d2b80fc9a5e08ff6  for sale  250,000.00
#
#                                        other_details  \
# 0  Appliances\nWater Heater\nWardrobes\nAmenities...
# 2
# 3
# 4
# 5  Appliances\nDishwasher\nMicrowave\nAir Conditi...
#
#                                               images currency duration  \
# 0  [https://efiewura.com/img/properties/executive...      GHS      N/A
# 2  [https://efiewura.com/img/properties/3_bedroom...      GHS      N/A
# 3  [https://efiewura.com/img/properties/3_bedroom...      GHS      N/A
# 4  [https://efiewura.com/img/properties/3_bedroom...      USD      N/A
# 5  [https://efiewura.com/img/properties/4_bedroom...      USD      N/A
#
#                  region   city    sub no_of_bedrooms no_of_bathrooms
# 0  Greater Accra Region  Accra  Other              4               4
# 2  Greater Accra Region  Other   Tema              3               3
# 3  Greater Accra Region  Other   Tema              3               3
# 4  Greater Accra Region  Other   Tema              3               2
# 5  Greater Accra Region  Accra  Legon              4               5

# %% [markdown]
# #### currency

# %%
df['currency'].unique()
# Out:
# array(['GHS', 'USD', 'GHC'], dtype=object)

# %%
df['currency_value'] = df['currency'].map({"USD":11.29,"GHC":1,"GHS":1})

# %%
df['price'] = df['price']*df['currency_value']

# %%
df.head()
# Out:
#                         _id  category      price  \
# 0  64c8106ad2b80fc9a5e08ff1  for sale   125000.0
# 2  64c8106dd2b80fc9a5e08ff3  for sale   165000.0
# 3  64c8106fd2b80fc9a5e08ff4  for sale   100000.0
# 4  64c81070d2b80fc9a5e08ff5  for sale  3161200.0
# 5  64c81072d2b80fc9a5e08ff6  for sale  2822500.0
#
#                                        other_details  \
# 0  Appliances\nWater Heater\nWardrobes\nAmenities...
# 2
# 3
# 4
# 5  Appliances\nDishwasher\nMicrowave\nAir Conditi...
#
#                                               images currency duration  \
# 0  [https://efiewura.com/img/properties/executive...      GHS      N/A
# 2  [https://efiewura.com/img/properties/3_bedroom...      GHS      N/A
# 3  [https://efiewura.com/img/properties/3_bedroom...      GHS      N/A
# 4  [https://efiewura.com/img/properties/3_bedroom...      USD      N/A
# 5  [https://efiewura.com/img/properties/4_bedroom...      USD      N/A
#
#                  region   city    sub no_of_bedrooms no_of_bathrooms  \
# 0  Greater Accra Region  Accra  Other              4               4
# 2  Greater Accra Region  Other   Tema              3               3
# 3  Greater Accra Region  Other   Tema              3               3
# 4  Greater Accra Region  Other   Tema              3               2
# 5  Greater Accra Region  Accra  Legon              4               5
#
#    currency_value
# 0            1.00
# 2            1.00
# 3            1.00
# 4           11.29
# 5           11.29

# %%
df['currency'] = df['currency'].replace("GHS","GHC")

# %%
df['currency'].unique()
# Out:
# array(['GHC', 'USD'], dtype=object)

# %%
df = df.rename(columns = {"currency":"accepted_currency"})

# %%
df = df.drop(columns=['region','_id','currency_value','category',"duration"],axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [515], in <cell line: 1>()
# ----> 1 df = df.drop(columns=['region','_id','currency_value','category',"duration"],axis = 1)
#
# File D:\Users\mk-armah\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File D:\Users\mk-armah\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File D:\Users\mk-armah\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File D:\Users\mk-armah\anaconda3\lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File D:\Users\mk-armah\anaconda3\lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File D:\Users\mk-armah\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['region', '_id', 'currency_value', 'category'] not found in axis"

# %%
df.isna().sum()
# Out:
# price                0
# other_details        0
# images               0
# accepted_currency    0
# duration             0
# city                 0
# sub                  0
# no_of_bedrooms       5
# no_of_bathrooms      5
# dtype: int64

# %%
df[df['other_details'] == ""]
# Out:
#          price other_details  \
# 2     165000.0
# 3     100000.0
# 4    3161200.0
# 243  1129000.0
# 300   846750.0
# 301  1072550.0
# 372  4064400.0
# 377  3387000.0
# 379  6762710.0
# 383  2258000.0
# 390  3387000.0
#
#                                                 images accepted_currency  \
# 2    [https://efiewura.com/img/properties/3_bedroom...               GHC
# 3    [https://efiewura.com/img/properties/3_bedroom...               GHC
# 4    [https://efiewura.com/img/properties/3_bedroom...               USD
# 243  [https://efiewura.com/img/properties/3_bedroom...               USD
# 300  [https://efiewura.com/img/properties/two_bedro...               USD
# 301  [https://efiewura.com/img/properties/three_bed...               USD
# 372  [https://efiewura.com/img/properties/executive...               USD
# 377  [https://efiewura.com/img/properties/6_bedroom...               USD
# 379  [https://efiewura.com/img/properties/executive...               USD
# 383  [https://efiewura.com/img/properties/4_bedroom...               USD
# 390  [https://efiewura.com/img/properties/4_bedroom...               USD
#
#     duration   city    sub no_of_bedrooms no_of_bathrooms
# 2        N/A  Other   Tema              3               3
# 3        N/A  Other   Tema              3               3
# 4        N/A  Other   Tema              3               2
# 243      N/A  Accra  Other              3               3
# 300      N/A  Other   Tema              2               2
# 301      N/A  Other   Tema              3               3
# 372      N/A  Accra  Other              4               4
# 377      N/A  Accra  Other             14              14
# 379      N/A  Accra   Tema              5               5
# 383      N/A  Accra  Other              4               4
# 390      N/A  Accra  Legon              4               4

# %%
df['other_details'] = df['other_details'].replace("",float("nan"))

# %%
df.isna().sum()
# Out:
# price                 0
# other_details        11
# images                0
# accepted_currency     0
# duration              0
# city                  0
# sub                   0
# no_of_bedrooms        5
# no_of_bathrooms       5
# dtype: int64

# %%
df.dropna().to_excel("cleaned_data.xlsx")

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Users\mk-armah\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File D:\Users\mk-armah\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\Users\mk-armah\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'house_details'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [524], in <cell line: 2>()
#       1 vectorizer = CountVectorizer(stop_words='english')
# ----> 2 X_text = vectorizer.fit_transform(df['house_details'])
#       4 # Combine BoW features with tabular data
#       5 X_tabular = StandardScaler().fit_transform(X_tabular)
#
# File D:\Users\mk-armah\anaconda3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File D:\Users\mk-armah\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'house_details'
